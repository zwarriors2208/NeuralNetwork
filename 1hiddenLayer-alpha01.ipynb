# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
###------------------------------
### global variables
##-----------------
RANDOM_STATE = 24
np.random.RandomState(seed = RANDOM_STATE)

N_SAMPLE  = 1000
NOISE = .2
ALPHA = .01
TEST_SIZE = .2
EPOCHS = 100000 #NO. of itersation used to optimize weights
# input and output directories

params = {'legend.fontsize' : 'medium', 
          'figure.figsize' : (15, 4),
          'axes.labelsize' : 'medium',
          'axes.titlesize' : 'large',
          'xtick.labelsize' : 'medium',
          'ytick.labelsize' : 'medium',
         }
loss_hist = {} # creating an empty dictionary which will store loss and epoch later so that we can make loss curve later

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm

# plt.style.use('seaborn-v0_8-darkgrid')
plt.style.use('ggplot')

# %%
X, y = datasets.make_moons(n_samples = N_SAMPLE, # n_samples: how many datasets in it
                          noise = NOISE, # peportion of randommness added to data so that it matched to real life data , without noise it becomes perfect half circle in moon dataset
                          shuffle = True, 
                          random_state = RANDOM_STATE)
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %% [markdown]
# # one hidden layer

# %%
def sigmoid(x):
    return 1 / ( 1 + np.exp(-x))

# %%
def fn_actv(z):
    return np.tanh(z)

# %%
def fn_actv_prime(z):
    return 1-(np.tanh(z))**2

# %%
fn_actv(np.array([[-1,0,1],[-np.inf, 0, np.inf]]))
# Out:
# array([[-0.76159416,  0.        ,  0.76159416],
#        [-1.        ,  0.        ,  1.        ]])

# %%
def predict(model, X_p): # this function will work as activation function
    W1, b1, W2, b2= model['W1'], model['b1'], model['W2'], model['b2']
    m=X_p.shape[0]
    ## forward propagation
    #layer 1
    z1 = X_p.dot(W1) + b1  # aggregation function
    a1 = fn_actv(z1) # activation funvtion
    # Layer 2
    z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
    a2 = sigmoid(z2) # activation
   
    return a2 >= 0.5

# %%
def fn_calculate_loss (model, X_l, y_l):
    W1, b1, W2, b2= model['W1'], model['b1'], model['W2'], model['b2']
    m=X_l.shape[0]
    ## forward propagation
    #layer 1
    z1 = X_l.dot(W1) + b1  # aggregation function
    a1 = fn_actv(z1) # activation funvtion
    # Layer 2
    z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
    a2 = sigmoid(z2) # activation
    data_loss = -y_l* np.log(a2)
    return data_loss.sum()/m

# %%
# features_df = data_df.drop('target', axis=1)
# labels= data_df['target']

# %%
X_train, X_test, y_train, y_test=   train_test_split(X,y , random_state= RANDOM_STATE, stratify=y, test_size= TEST_SIZE)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %%
rng = np.random.default_rng(seed = RANDOM_STATE)

def build_model(nn_hdim, X_t, y_t, n_epoch = EPOCHS, alpha = ALPHA): # nn_hdim:- no of hidden layers 
    '''
    2-4-1
    '''
    # get dimensions for weight in it
    m, nn_input_dim = X_t.shape # m is no of rows
    nn_output_shape = y_t.shape[1]
    # initializing weighs randomly using numoy generator
    W1 = rng.random((nn_input_dim, nn_hdim), dtype= np.float32) / np.sqrt(nn_input_dim)
    W2 = rng.random((nn_hdim, nn_output_shape), dtype = np.float32)/ np.sqrt(nn_hdim)

    # initializing bias 
    b1 = np.zeros((1, nn_hdim), dtype = np.float32)
    b2 = np.zeros((1, nn_output_shape), dtype = np.float32)

    curr_loss = 0
    loss = []
    epoch = []
    for i in range(n_epoch):
        ## forward propagation
        #layer 1
        z1 = X_t.dot(W1) + b1  # aggregation function
        a1 = fn_actv(z1) # activation funvtion
        # Layer 2
        z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
        a2 = sigmoid(z2) # activation

        ## backpropagation
        # print(y.shape)
        dz2 = a2 - y_t # y should be of shape (1, m)
        dW2 = (a1.T).dot(dz2)
        assert (W2.shape == dW2.shape), f'Shape: W2-{W2.shape} and dw2-{dW2.shape}'

        db2 = np.sum(dz2, axis = 0, keepdims = True)
        assert (b2.shape == db2.shape), f'Shape: b2-{b2.shape} and db2-{db2.shape}'
        da1 = dz2.dot(W2.T)
        assert (a1.shape == da1.shape), f'Shape: a1-{a1.shape} and da1-{da1.shape}'

        # layer 1
        dz1 = da1 * fn_actv_prime(z1)
        assert (z1.shape == dz1.shape), f'Shape: z1-{z1.shape} and dz1-{dz1.shape}'
        dW1 = (X_t.T).dot(dz1)
        assert (W1.shape== dW1.shape), f'Shape: W1-{W1.shape} and dW1-{dW1.shape}'
        db1= np.sum(dz1, axis=0, keepdims=True)
        assert (b1.shape== db1.shape), f'Shape: b1-{b1.shape} and db1-{db1.shape}'

        #### Gradient Updates

        W1 += - alpha *dW1/m
        W2 += - alpha *dW2/m
        b1 += - alpha *db1/m
        b2 += - alpha *db2/m
        model = {'W1':W1, 'b1': b1, 'W2': W2, 'b2' : b2}

        if i%100 == 0:
            curr_loss = fn_calculate_loss(model, X_t, y_t)
            loss.append(curr_loss)
            epoch.append(i)
            
        if i%1000 == 0:
            print(f'Loss after {i:>5d} epochs : {curr_loss:0.5f}')


    loss_hist['epoch'] = epoch
    loss_hist['loss'] = loss

    return model

# %%
model  = build_model(4, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.29121
# Loss after  1000 epochs : 0.22896
# Loss after  2000 epochs : 0.17582
# Loss after  3000 epochs : 0.15713
# Loss after  4000 epochs : 0.15185
# Loss after  5000 epochs : 0.15021
# Loss after  6000 epochs : 0.14953
# Loss after  7000 epochs : 0.14912
# Loss after  8000 epochs : 0.14880
# Loss after  9000 epochs : 0.14850
# Loss after 10000 epochs : 0.14814
# Loss after 11000 epochs : 0.14765
# Loss after 12000 epochs : 0.14690
# Loss after 13000 epochs : 0.14565
# Loss after 14000 epochs : 0.14361
# Loss after 15000 epochs : 0.14049
# Loss after 16000 epochs : 0.13623
# Loss after 17000 epochs : 0.13105
# Loss after 18000 epochs : 0.12537
# Loss after 19000 epochs : 0.11964
# Loss after 20000 epochs : 0.11415
# Loss after 21000 epochs : 0.10906
# Loss after 22000 epochs : 0.10443
# Loss after 23000 epochs : 0.10025
# Loss after 24000 epochs : 0.09648
# Loss after 25000 epochs : 0.09307
# Loss after 26000 epochs : 0.08998
# Loss after 27000 epochs : 0.08717
# Loss after 28000 epochs : 0.08459
# Loss after 29000 epochs : 0.08221
# Loss after 30000 epochs : 0.07999
# Loss after 31000 epochs : 0.07790
# Loss after 32000 epochs : 0.07592
# Loss after 33000 epochs : 0.07401
# Loss after 34000 epochs : 0.07213
# Loss after 35000 epochs : 0.07026
# Loss after 36000 epochs : 0.06837
# Loss after 37000 epochs : 0.06642
# Loss after 38000 epochs : 0.06441
# Loss after 39000 epochs : 0.06232
# Loss after 40000 epochs : 0.06018
# Loss after 41000 epochs : 0.05802
# Loss after 42000 epochs : 0.05589
# Loss after 43000 epochs : 0.05383
# Loss after 44000 epochs : 0.05188
# Loss after 45000 epochs : 0.05007
# Loss after 46000 epochs : 0.04839
# Loss after 47000 epochs : 0.04686
# Loss after 48000 epochs : 0.04546
# Loss after 49000 epochs : 0.04419
# Loss after 50000 epochs : 0.04303
# Loss after 51000 epochs : 0.04198
# Loss after 52000 epochs : 0.04101
# Loss after 53000 epochs : 0.04013
# Loss after 54000 epochs : 0.03932
# Loss after 55000 epochs : 0.03858
# Loss after 56000 epochs : 0.03789
# Loss after 57000 epochs : 0.03726
# Loss after 58000 epochs : 0.03668
# Loss after 59000 epochs : 0.03614
# Loss after 60000 epochs : 0.03564
# Loss after 61000 epochs : 0.03517
# Loss after 62000 epochs : 0.03474
# Loss after 63000 epochs : 0.03434
# Loss after 64000 epochs : 0.03397
# Loss after 65000 epochs : 0.03363
# Loss after 66000 epochs : 0.03331
# Loss after 67000 epochs : 0.03301
# Loss after 68000 epochs : 0.03273
# Loss after 69000 epochs : 0.03247
# Loss after 70000 epochs : 0.03223
# Loss after 71000 epochs : 0.03200
# Loss after 72000 epochs : 0.03179
# Loss after 73000 epochs : 0.03160
# Loss after 74000 epochs : 0.03141
# Loss after 75000 epochs : 0.03124
# Loss after 76000 epochs : 0.03108
# Loss after 77000 epochs : 0.03093
# Loss after 78000 epochs : 0.03079
# Loss after 79000 epochs : 0.03066
# Loss after 80000 epochs : 0.03053
# Loss after 81000 epochs : 0.03041
# Loss after 82000 epochs : 0.03030
# Loss after 83000 epochs : 0.03020
# Loss after 84000 epochs : 0.03010
# Loss after 85000 epochs : 0.03001
# Loss after 86000 epochs : 0.02992
# Loss after 87000 epochs : 0.02983
# Loss after 88000 epochs : 0.02976
# Loss after 89000 epochs : 0.02968
# Loss after 90000 epochs : 0.02961
# Loss after 91000 epochs : 0.02954
# Loss after 92000 epochs : 0.02948
# Loss after 93000 epochs : 0.02942
# Loss after 94000 epochs : 0.02936
# Loss after 95000 epochs : 0.02931
# Loss after 96000 epochs : 0.02925
# Loss after 97000 epochs : 0.02920
# Loss after 98000 epochs : 0.02916
# Loss after 99000 epochs : 0.02911

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.9825

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.965

# %%
cm = confusion_matrix(y_test, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
def fn_plot_decision_boundry(model, X, y, X_ts, y_ts): # x, y are trainig data, X_ts, y_ts are test data
    fig, ax = plt.subplots(figsize =(8,5))
    dm=0.01 # spacing of the grid width
    
    #Min and max along two axis
    x_min, x_max = X[:,0].min(), X[:,0].max()
    y_min, y_max = X[:,1].min(), X[:,1].max()

    # generate a mesh grid
    xx,yy = np.meshgrid(np.arange(x_min, x_max, dm), # creates an array of x-cordinates y no of times
                       np.arange(y_min, y_max, dm)) # creates an array of y-cordinates x no of times
    # Together they create a mesh\
    
    XX = np.c_[xx.ravel(), yy.ravel()]
    
    y_pred= predict(model, XX)

    
    Z = np.array(y_pred).reshape(xx.shape)

    ax.contourf(xx,yy, Z, alpha=0.8, cmap= plt.cm.Paired)
    ax.scatter(X[:,0], X[:,1], c = y, edgecolors='k', cmap= CMAP)
    ax.scatter(X_ts[:,0], X_ts[:,1], c = y_ts, edgecolors='k', cmap= CMAP,marker='*')

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with one neuron in hidden layer

# %%
model  = build_model(1, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.32693
# Loss after  1000 epochs : 0.29428
# Loss after  2000 epochs : 0.21928
# Loss after  3000 epochs : 0.17528
# Loss after  4000 epochs : 0.16046
# Loss after  5000 epochs : 0.15604
# Loss after  6000 epochs : 0.15439
# Loss after  7000 epochs : 0.15355
# Loss after  8000 epochs : 0.15300
# Loss after  9000 epochs : 0.15257
# Loss after 10000 epochs : 0.15221
# Loss after 11000 epochs : 0.15190
# Loss after 12000 epochs : 0.15162
# Loss after 13000 epochs : 0.15137
# Loss after 14000 epochs : 0.15114
# Loss after 15000 epochs : 0.15093
# Loss after 16000 epochs : 0.15074
# Loss after 17000 epochs : 0.15057
# Loss after 18000 epochs : 0.15040
# Loss after 19000 epochs : 0.15025
# Loss after 20000 epochs : 0.15012
# Loss after 21000 epochs : 0.14999
# Loss after 22000 epochs : 0.14987
# Loss after 23000 epochs : 0.14975
# Loss after 24000 epochs : 0.14965
# Loss after 25000 epochs : 0.14955
# Loss after 26000 epochs : 0.14946
# Loss after 27000 epochs : 0.14937
# Loss after 28000 epochs : 0.14929
# Loss after 29000 epochs : 0.14921
# Loss after 30000 epochs : 0.14913
# Loss after 31000 epochs : 0.14906
# Loss after 32000 epochs : 0.14900
# Loss after 33000 epochs : 0.14893
# Loss after 34000 epochs : 0.14887
# Loss after 35000 epochs : 0.14882
# Loss after 36000 epochs : 0.14876
# Loss after 37000 epochs : 0.14871
# Loss after 38000 epochs : 0.14866
# Loss after 39000 epochs : 0.14861
# Loss after 40000 epochs : 0.14856
# Loss after 41000 epochs : 0.14852
# Loss after 42000 epochs : 0.14847
# Loss after 43000 epochs : 0.14843
# Loss after 44000 epochs : 0.14839
# Loss after 45000 epochs : 0.14836
# Loss after 46000 epochs : 0.14832
# Loss after 47000 epochs : 0.14828
# Loss after 48000 epochs : 0.14825
# Loss after 49000 epochs : 0.14821
# Loss after 50000 epochs : 0.14818
# Loss after 51000 epochs : 0.14815
# Loss after 52000 epochs : 0.14812
# Loss after 53000 epochs : 0.14809
# Loss after 54000 epochs : 0.14806
# Loss after 55000 epochs : 0.14804
# Loss after 56000 epochs : 0.14801
# Loss after 57000 epochs : 0.14798
# Loss after 58000 epochs : 0.14796
# Loss after 59000 epochs : 0.14793
# Loss after 60000 epochs : 0.14791
# Loss after 61000 epochs : 0.14789
# Loss after 62000 epochs : 0.14786
# Loss after 63000 epochs : 0.14784
# Loss after 64000 epochs : 0.14782
# Loss after 65000 epochs : 0.14780
# Loss after 66000 epochs : 0.14778
# Loss after 67000 epochs : 0.14776
# Loss after 68000 epochs : 0.14774
# Loss after 69000 epochs : 0.14772
# Loss after 70000 epochs : 0.14770
# Loss after 71000 epochs : 0.14768
# Loss after 72000 epochs : 0.14766
# Loss after 73000 epochs : 0.14765
# Loss after 74000 epochs : 0.14763
# Loss after 75000 epochs : 0.14761
# Loss after 76000 epochs : 0.14760
# Loss after 77000 epochs : 0.14758
# Loss after 78000 epochs : 0.14756
# Loss after 79000 epochs : 0.14755
# Loss after 80000 epochs : 0.14753
# Loss after 81000 epochs : 0.14752
# Loss after 82000 epochs : 0.14750
# Loss after 83000 epochs : 0.14749
# Loss after 84000 epochs : 0.14748
# Loss after 85000 epochs : 0.14746
# Loss after 86000 epochs : 0.14745
# Loss after 87000 epochs : 0.14744
# Loss after 88000 epochs : 0.14742
# Loss after 89000 epochs : 0.14741
# Loss after 90000 epochs : 0.14740
# Loss after 91000 epochs : 0.14739
# Loss after 92000 epochs : 0.14737
# Loss after 93000 epochs : 0.14736
# Loss after 94000 epochs : 0.14735
# Loss after 95000 epochs : 0.14734
# Loss after 96000 epochs : 0.14733
# Loss after 97000 epochs : 0.14732
# Loss after 98000 epochs : 0.14731
# Loss after 99000 epochs : 0.14730

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.8725

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.855

# %%
cm = confusion_matrix(y_test, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with 10 neurons in hidden layer

# %%
model  = build_model(10, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.27273
# Loss after  1000 epochs : 0.19882
# Loss after  2000 epochs : 0.16276
# Loss after  3000 epochs : 0.15141
# Loss after  4000 epochs : 0.14770
# Loss after  5000 epochs : 0.14572
# Loss after  6000 epochs : 0.14381
# Loss after  7000 epochs : 0.14138
# Loss after  8000 epochs : 0.13812
# Loss after  9000 epochs : 0.13386
# Loss after 10000 epochs : 0.12862
# Loss after 11000 epochs : 0.12265
# Loss after 12000 epochs : 0.11629
# Loss after 13000 epochs : 0.10989
# Loss after 14000 epochs : 0.10373
# Loss after 15000 epochs : 0.09798
# Loss after 16000 epochs : 0.09272
# Loss after 17000 epochs : 0.08798
# Loss after 18000 epochs : 0.08373
# Loss after 19000 epochs : 0.07993
# Loss after 20000 epochs : 0.07654
# Loss after 21000 epochs : 0.07352
# Loss after 22000 epochs : 0.07081
# Loss after 23000 epochs : 0.06838
# Loss after 24000 epochs : 0.06619
# Loss after 25000 epochs : 0.06421
# Loss after 26000 epochs : 0.06241
# Loss after 27000 epochs : 0.06076
# Loss after 28000 epochs : 0.05925
# Loss after 29000 epochs : 0.05786
# Loss after 30000 epochs : 0.05657
# Loss after 31000 epochs : 0.05537
# Loss after 32000 epochs : 0.05424
# Loss after 33000 epochs : 0.05319
# Loss after 34000 epochs : 0.05219
# Loss after 35000 epochs : 0.05125
# Loss after 36000 epochs : 0.05035
# Loss after 37000 epochs : 0.04950
# Loss after 38000 epochs : 0.04868
# Loss after 39000 epochs : 0.04790
# Loss after 40000 epochs : 0.04714
# Loss after 41000 epochs : 0.04641
# Loss after 42000 epochs : 0.04571
# Loss after 43000 epochs : 0.04503
# Loss after 44000 epochs : 0.04438
# Loss after 45000 epochs : 0.04374
# Loss after 46000 epochs : 0.04313
# Loss after 47000 epochs : 0.04254
# Loss after 48000 epochs : 0.04197
# Loss after 49000 epochs : 0.04143
# Loss after 50000 epochs : 0.04090
# Loss after 51000 epochs : 0.04040
# Loss after 52000 epochs : 0.03991
# Loss after 53000 epochs : 0.03945
# Loss after 54000 epochs : 0.03901
# Loss after 55000 epochs : 0.03858
# Loss after 56000 epochs : 0.03818
# Loss after 57000 epochs : 0.03779
# Loss after 58000 epochs : 0.03741
# Loss after 59000 epochs : 0.03706
# Loss after 60000 epochs : 0.03671
# Loss after 61000 epochs : 0.03639
# Loss after 62000 epochs : 0.03607
# Loss after 63000 epochs : 0.03577
# Loss after 64000 epochs : 0.03548
# Loss after 65000 epochs : 0.03521
# Loss after 66000 epochs : 0.03494
# Loss after 67000 epochs : 0.03469
# Loss after 68000 epochs : 0.03444
# Loss after 69000 epochs : 0.03420
# Loss after 70000 epochs : 0.03398
# Loss after 71000 epochs : 0.03376
# Loss after 72000 epochs : 0.03355
# Loss after 73000 epochs : 0.03335
# Loss after 74000 epochs : 0.03316
# Loss after 75000 epochs : 0.03297
# Loss after 76000 epochs : 0.03279
# Loss after 77000 epochs : 0.03262
# Loss after 78000 epochs : 0.03246
# Loss after 79000 epochs : 0.03230
# Loss after 80000 epochs : 0.03215
# Loss after 81000 epochs : 0.03200
# Loss after 82000 epochs : 0.03186
# Loss after 83000 epochs : 0.03173
# Loss after 84000 epochs : 0.03160
# Loss after 85000 epochs : 0.03147
# Loss after 86000 epochs : 0.03135
# Loss after 87000 epochs : 0.03124
# Loss after 88000 epochs : 0.03113
# Loss after 89000 epochs : 0.03102
# Loss after 90000 epochs : 0.03092
# Loss after 91000 epochs : 0.03083
# Loss after 92000 epochs : 0.03073
# Loss after 93000 epochs : 0.03064
# Loss after 94000 epochs : 0.03056
# Loss after 95000 epochs : 0.03047
# Loss after 96000 epochs : 0.03039
# Loss after 97000 epochs : 0.03031
# Loss after 98000 epochs : 0.03024
# Loss after 99000 epochs : 0.03017

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.9775

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.96

# %%
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with 50 neurons in hidden layer

# %%
model  = build_model(50, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.19854
# Loss after  1000 epochs : 0.17077
# Loss after  2000 epochs : 0.15311
# Loss after  3000 epochs : 0.14860
# Loss after  4000 epochs : 0.14666
# Loss after  5000 epochs : 0.14531
# Loss after  6000 epochs : 0.14406
# Loss after  7000 epochs : 0.14270
# Loss after  8000 epochs : 0.14110
# Loss after  9000 epochs : 0.13910
# Loss after 10000 epochs : 0.13655
# Loss after 11000 epochs : 0.13325
# Loss after 12000 epochs : 0.12903
# Loss after 13000 epochs : 0.12377
# Loss after 14000 epochs : 0.11750
# Loss after 15000 epochs : 0.11044
# Loss after 16000 epochs : 0.10298
# Loss after 17000 epochs : 0.09557
# Loss after 18000 epochs : 0.08858
# Loss after 19000 epochs : 0.08225
# Loss after 20000 epochs : 0.07668
# Loss after 21000 epochs : 0.07185
# Loss after 22000 epochs : 0.06770
# Loss after 23000 epochs : 0.06415
# Loss after 24000 epochs : 0.06110
# Loss after 25000 epochs : 0.05847
# Loss after 26000 epochs : 0.05620
# Loss after 27000 epochs : 0.05421
# Loss after 28000 epochs : 0.05247
# Loss after 29000 epochs : 0.05093
# Loss after 30000 epochs : 0.04956
# Loss after 31000 epochs : 0.04834
# Loss after 32000 epochs : 0.04724
# Loss after 33000 epochs : 0.04625
# Loss after 34000 epochs : 0.04535
# Loss after 35000 epochs : 0.04453
# Loss after 36000 epochs : 0.04378
# Loss after 37000 epochs : 0.04309
# Loss after 38000 epochs : 0.04246
# Loss after 39000 epochs : 0.04187
# Loss after 40000 epochs : 0.04133
# Loss after 41000 epochs : 0.04082
# Loss after 42000 epochs : 0.04035
# Loss after 43000 epochs : 0.03991
# Loss after 44000 epochs : 0.03949
# Loss after 45000 epochs : 0.03910
# Loss after 46000 epochs : 0.03874
# Loss after 47000 epochs : 0.03839
# Loss after 48000 epochs : 0.03807
# Loss after 49000 epochs : 0.03776
# Loss after 50000 epochs : 0.03747
# Loss after 51000 epochs : 0.03720
# Loss after 52000 epochs : 0.03693
# Loss after 53000 epochs : 0.03669
# Loss after 54000 epochs : 0.03645
# Loss after 55000 epochs : 0.03622
# Loss after 56000 epochs : 0.03601
# Loss after 57000 epochs : 0.03580
# Loss after 58000 epochs : 0.03561
# Loss after 59000 epochs : 0.03542
# Loss after 60000 epochs : 0.03524
# Loss after 61000 epochs : 0.03507
# Loss after 62000 epochs : 0.03490
# Loss after 63000 epochs : 0.03474
# Loss after 64000 epochs : 0.03459
# Loss after 65000 epochs : 0.03445
# Loss after 66000 epochs : 0.03431
# Loss after 67000 epochs : 0.03417
# Loss after 68000 epochs : 0.03404
# Loss after 69000 epochs : 0.03391
# Loss after 70000 epochs : 0.03379
# Loss after 71000 epochs : 0.03368
# Loss after 72000 epochs : 0.03356
# Loss after 73000 epochs : 0.03345
# Loss after 74000 epochs : 0.03335
# Loss after 75000 epochs : 0.03324
# Loss after 76000 epochs : 0.03315
# Loss after 77000 epochs : 0.03305
# Loss after 78000 epochs : 0.03296
# Loss after 79000 epochs : 0.03287
# Loss after 80000 epochs : 0.03278
# Loss after 81000 epochs : 0.03269
# Loss after 82000 epochs : 0.03261
# Loss after 83000 epochs : 0.03253
# Loss after 84000 epochs : 0.03245
# Loss after 85000 epochs : 0.03238
# Loss after 86000 epochs : 0.03230
# Loss after 87000 epochs : 0.03223
# Loss after 88000 epochs : 0.03216
# Loss after 89000 epochs : 0.03209
# Loss after 90000 epochs : 0.03202
# Loss after 91000 epochs : 0.03196
# Loss after 92000 epochs : 0.03189
# Loss after 93000 epochs : 0.03183
# Loss after 94000 epochs : 0.03177
# Loss after 95000 epochs : 0.03171
# Loss after 96000 epochs : 0.03165
# Loss after 97000 epochs : 0.03160
# Loss after 98000 epochs : 0.03154
# Loss after 99000 epochs : 0.03149

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.9775

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.96

# %%
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)
