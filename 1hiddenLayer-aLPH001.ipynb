# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
###------------------------------
### global variables
##-----------------
RANDOM_STATE = 24
np.random.RandomState(seed = RANDOM_STATE)

N_SAMPLE  = 1000
NOISE = .2
ALPHA = .001 ## very small alpha is bad idea -
TEST_SIZE = .2
EPOCHS = 100000 #NO. of itersation used to optimize weights
# input and output directories

params = {'legend.fontsize' : 'medium', 
          'figure.figsize' : (15, 4),
          'axes.labelsize' : 'medium',
          'axes.titlesize' : 'large',
          'xtick.labelsize' : 'medium',
          'ytick.labelsize' : 'medium',
         }
loss_hist = {} # creating an empty dictionary which will store loss and epoch later so that we can make loss curve later

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm

# plt.style.use('seaborn-v0_8-darkgrid')
plt.style.use('ggplot')

# %%
X, y = datasets.make_moons(n_samples = N_SAMPLE, # n_samples: how many datasets in it
                          noise = NOISE, # peportion of randommness added to data so that it matched to real life data , without noise it becomes perfect half circle in moon dataset
                          shuffle = True, 
                          random_state = RANDOM_STATE)
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %% [markdown]
# # one hidden layer

# %%
def sigmoid(x):
    return 1 / ( 1 + np.exp(-x))

# %%
def fn_actv(z):
    return np.tanh(z)

# %%
def fn_actv_prime(z):
    return 1-(np.tanh(z))**2

# %%
fn_actv(np.array([[-1,0,1],[-np.inf, 0, np.inf]]))
# Out:
# array([[-0.76159416,  0.        ,  0.76159416],
#        [-1.        ,  0.        ,  1.        ]])

# %%
def predict(model, X_p): # this function will work as activation function
    W1, b1, W2, b2= model['W1'], model['b1'], model['W2'], model['b2']
    m=X_p.shape[0]
    ## forward propagation
    #layer 1
    z1 = X_p.dot(W1) + b1  # aggregation function
    a1 = fn_actv(z1) # activation funvtion
    # Layer 2
    z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
    a2 = sigmoid(z2) # activation
   
    return a2 >= 0.5

# %%
def fn_calculate_loss (model, X_l, y_l):
    W1, b1, W2, b2= model['W1'], model['b1'], model['W2'], model['b2']
    m=X_l.shape[0]
    ## forward propagation
    #layer 1
    z1 = X_l.dot(W1) + b1  # aggregation function
    a1 = fn_actv(z1) # activation funvtion
    # Layer 2
    z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
    a2 = sigmoid(z2) # activation
    data_loss = -y_l* np.log(a2)
    return data_loss.sum()/m

# %%
# features_df = data_df.drop('target', axis=1)
# labels= data_df['target']

# %%
X_train, X_test, y_train, y_test=   train_test_split(X,y , random_state= RANDOM_STATE, stratify=y, test_size= TEST_SIZE)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %%
rng = np.random.default_rng(seed = RANDOM_STATE)

def build_model(nn_hdim, X_t, y_t, n_epoch = EPOCHS, alpha = ALPHA): # nn_hdim:- no of hidden layers 
    '''
    2-4-1
    '''
    # get dimensions for weight in it
    m, nn_input_dim = X_t.shape # m is no of rows
    nn_output_shape = y_t.shape[1]
    # initializing weighs randomly using numoy generator
    W1 = rng.random((nn_input_dim, nn_hdim), dtype= np.float32) / np.sqrt(nn_input_dim)
    W2 = rng.random((nn_hdim, nn_output_shape), dtype = np.float32)/ np.sqrt(nn_hdim)

    # initializing bias 
    b1 = np.zeros((1, nn_hdim), dtype = np.float32)
    b2 = np.zeros((1, nn_output_shape), dtype = np.float32)

    curr_loss = 0
    loss = []
    epoch = []
    for i in range(n_epoch):
        ## forward propagation
        #layer 1
        z1 = X_t.dot(W1) + b1  # aggregation function
        a1 = fn_actv(z1) # activation funvtion
        # Layer 2
        z2 = a1.dot(W2) + b2 # aggregation function for hidden layer
        a2 = sigmoid(z2) # activation

        ## backpropagation
        # print(y.shape)
        dz2 = a2 - y_t # y should be of shape (1, m)
        dW2 = (a1.T).dot(dz2)
        assert (W2.shape == dW2.shape), f'Shape: W2-{W2.shape} and dw2-{dW2.shape}'

        db2 = np.sum(dz2, axis = 0, keepdims = True)
        assert (b2.shape == db2.shape), f'Shape: b2-{b2.shape} and db2-{db2.shape}'
        da1 = dz2.dot(W2.T)
        assert (a1.shape == da1.shape), f'Shape: a1-{a1.shape} and da1-{da1.shape}'

        # layer 1
        dz1 = da1 * fn_actv_prime(z1)
        assert (z1.shape == dz1.shape), f'Shape: z1-{z1.shape} and dz1-{dz1.shape}'
        dW1 = (X_t.T).dot(dz1)
        assert (W1.shape== dW1.shape), f'Shape: W1-{W1.shape} and dW1-{dW1.shape}'
        db1= np.sum(dz1, axis=0, keepdims=True)
        assert (b1.shape== db1.shape), f'Shape: b1-{b1.shape} and db1-{db1.shape}'

        #### Gradient Updates

        W1 += - alpha *dW1/m
        W2 += - alpha *dW2/m
        b1 += - alpha *db1/m
        b2 += - alpha *db2/m
        model = {'W1':W1, 'b1': b1, 'W2': W2, 'b2' : b2}

        if i%100 == 0:
            curr_loss = fn_calculate_loss(model, X_t, y_t)
            loss.append(curr_loss)
            epoch.append(i)
            
        if i%1000 == 0:
            print(f'Loss after {i:>5d} epochs : {curr_loss:0.5f}')


    loss_hist['epoch'] = epoch
    loss_hist['loss'] = loss

    return model

# %%
model  = build_model(4, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.29116
# Loss after  1000 epochs : 0.29453
# Loss after  2000 epochs : 0.29366
# Loss after  3000 epochs : 0.28927
# Loss after  4000 epochs : 0.28231
# Loss after  5000 epochs : 0.27376
# Loss after  6000 epochs : 0.26447
# Loss after  7000 epochs : 0.25504
# Loss after  8000 epochs : 0.24586
# Loss after  9000 epochs : 0.23715
# Loss after 10000 epochs : 0.22900
# Loss after 11000 epochs : 0.22143
# Loss after 12000 epochs : 0.21442
# Loss after 13000 epochs : 0.20796
# Loss after 14000 epochs : 0.20202
# Loss after 15000 epochs : 0.19657
# Loss after 16000 epochs : 0.19158
# Loss after 17000 epochs : 0.18704
# Loss after 18000 epochs : 0.18292
# Loss after 19000 epochs : 0.17919
# Loss after 20000 epochs : 0.17583
# Loss after 21000 epochs : 0.17282
# Loss after 22000 epochs : 0.17013
# Loss after 23000 epochs : 0.16773
# Loss after 24000 epochs : 0.16560
# Loss after 25000 epochs : 0.16371
# Loss after 26000 epochs : 0.16205
# Loss after 27000 epochs : 0.16057
# Loss after 28000 epochs : 0.15928
# Loss after 29000 epochs : 0.15814
# Loss after 30000 epochs : 0.15714
# Loss after 31000 epochs : 0.15626
# Loss after 32000 epochs : 0.15549
# Loss after 33000 epochs : 0.15481
# Loss after 34000 epochs : 0.15421
# Loss after 35000 epochs : 0.15369
# Loss after 36000 epochs : 0.15322
# Loss after 37000 epochs : 0.15282
# Loss after 38000 epochs : 0.15245
# Loss after 39000 epochs : 0.15214
# Loss after 40000 epochs : 0.15185
# Loss after 41000 epochs : 0.15160
# Loss after 42000 epochs : 0.15137
# Loss after 43000 epochs : 0.15117
# Loss after 44000 epochs : 0.15099
# Loss after 45000 epochs : 0.15083
# Loss after 46000 epochs : 0.15068
# Loss after 47000 epochs : 0.15055
# Loss after 48000 epochs : 0.15043
# Loss after 49000 epochs : 0.15032
# Loss after 50000 epochs : 0.15021
# Loss after 51000 epochs : 0.15012
# Loss after 52000 epochs : 0.15003
# Loss after 53000 epochs : 0.14996
# Loss after 54000 epochs : 0.14988
# Loss after 55000 epochs : 0.14981
# Loss after 56000 epochs : 0.14975
# Loss after 57000 epochs : 0.14969
# Loss after 58000 epochs : 0.14963
# Loss after 59000 epochs : 0.14958
# Loss after 60000 epochs : 0.14953
# Loss after 61000 epochs : 0.14948
# Loss after 62000 epochs : 0.14943
# Loss after 63000 epochs : 0.14939
# Loss after 64000 epochs : 0.14935
# Loss after 65000 epochs : 0.14930
# Loss after 66000 epochs : 0.14927
# Loss after 67000 epochs : 0.14923
# Loss after 68000 epochs : 0.14919
# Loss after 69000 epochs : 0.14916
# Loss after 70000 epochs : 0.14912
# Loss after 71000 epochs : 0.14909
# Loss after 72000 epochs : 0.14905
# Loss after 73000 epochs : 0.14902
# Loss after 74000 epochs : 0.14899
# Loss after 75000 epochs : 0.14896
# Loss after 76000 epochs : 0.14892
# Loss after 77000 epochs : 0.14889
# Loss after 78000 epochs : 0.14886
# Loss after 79000 epochs : 0.14884
# Loss after 80000 epochs : 0.14881
# Loss after 81000 epochs : 0.14878
# Loss after 82000 epochs : 0.14875
# Loss after 83000 epochs : 0.14872
# Loss after 84000 epochs : 0.14869
# Loss after 85000 epochs : 0.14866
# Loss after 86000 epochs : 0.14863
# Loss after 87000 epochs : 0.14860
# Loss after 88000 epochs : 0.14856
# Loss after 89000 epochs : 0.14853
# Loss after 90000 epochs : 0.14850
# Loss after 91000 epochs : 0.14847
# Loss after 92000 epochs : 0.14844
# Loss after 93000 epochs : 0.14840
# Loss after 94000 epochs : 0.14837
# Loss after 95000 epochs : 0.14833
# Loss after 96000 epochs : 0.14830
# Loss after 97000 epochs : 0.14826
# Loss after 98000 epochs : 0.14823
# Loss after 99000 epochs : 0.14819

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.875

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.855

# %%
cm = confusion_matrix(y_test, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
def fn_plot_decision_boundry(model, X, y, X_ts, y_ts): # x, y are trainig data, X_ts, y_ts are test data
    fig, ax = plt.subplots(figsize =(8,5))
    dm=0.01 # spacing of the grid width
    
    #Min and max along two axis
    x_min, x_max = X[:,0].min(), X[:,0].max()
    y_min, y_max = X[:,1].min(), X[:,1].max()

    # generate a mesh grid
    xx,yy = np.meshgrid(np.arange(x_min, x_max, dm), # creates an array of x-cordinates y no of times
                       np.arange(y_min, y_max, dm)) # creates an array of y-cordinates x no of times
    # Together they create a mesh\
    
    XX = np.c_[xx.ravel(), yy.ravel()]
    
    y_pred= predict(model, XX)

    
    Z = np.array(y_pred).reshape(xx.shape)

    ax.contourf(xx,yy, Z, alpha=0.8, cmap= plt.cm.Paired)
    ax.scatter(X[:,0], X[:,1], c = y, edgecolors='k', cmap= CMAP)
    ax.scatter(X_ts[:,0], X_ts[:,1], c = y_ts, edgecolors='k', cmap= CMAP,marker='*')

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with one neuron in hidden layer

# %%
model  = build_model(1, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.32690
# Loss after  1000 epochs : 0.32990
# Loss after  2000 epochs : 0.33138
# Loss after  3000 epochs : 0.33124
# Loss after  4000 epochs : 0.32954
# Loss after  5000 epochs : 0.32637
# Loss after  6000 epochs : 0.32188
# Loss after  7000 epochs : 0.31621
# Loss after  8000 epochs : 0.30957
# Loss after  9000 epochs : 0.30218
# Loss after 10000 epochs : 0.29429
# Loss after 11000 epochs : 0.28616
# Loss after 12000 epochs : 0.27798
# Loss after 13000 epochs : 0.26989
# Loss after 14000 epochs : 0.26197
# Loss after 15000 epochs : 0.25425
# Loss after 16000 epochs : 0.24676
# Loss after 17000 epochs : 0.23950
# Loss after 18000 epochs : 0.23248
# Loss after 19000 epochs : 0.22573
# Loss after 20000 epochs : 0.21927
# Loss after 21000 epochs : 0.21314
# Loss after 22000 epochs : 0.20737
# Loss after 23000 epochs : 0.20198
# Loss after 24000 epochs : 0.19700
# Loss after 25000 epochs : 0.19242
# Loss after 26000 epochs : 0.18825
# Loss after 27000 epochs : 0.18446
# Loss after 28000 epochs : 0.18106
# Loss after 29000 epochs : 0.17800
# Loss after 30000 epochs : 0.17528
# Loss after 31000 epochs : 0.17286
# Loss after 32000 epochs : 0.17071
# Loss after 33000 epochs : 0.16881
# Loss after 34000 epochs : 0.16713
# Loss after 35000 epochs : 0.16564
# Loss after 36000 epochs : 0.16433
# Loss after 37000 epochs : 0.16318
# Loss after 38000 epochs : 0.16216
# Loss after 39000 epochs : 0.16126
# Loss after 40000 epochs : 0.16047
# Loss after 41000 epochs : 0.15977
# Loss after 42000 epochs : 0.15914
# Loss after 43000 epochs : 0.15859
# Loss after 44000 epochs : 0.15809
# Loss after 45000 epochs : 0.15765
# Loss after 46000 epochs : 0.15726
# Loss after 47000 epochs : 0.15691
# Loss after 48000 epochs : 0.15659
# Loss after 49000 epochs : 0.15630
# Loss after 50000 epochs : 0.15604
# Loss after 51000 epochs : 0.15581
# Loss after 52000 epochs : 0.15559
# Loss after 53000 epochs : 0.15540
# Loss after 54000 epochs : 0.15522
# Loss after 55000 epochs : 0.15505
# Loss after 56000 epochs : 0.15490
# Loss after 57000 epochs : 0.15476
# Loss after 58000 epochs : 0.15463
# Loss after 59000 epochs : 0.15451
# Loss after 60000 epochs : 0.15439
# Loss after 61000 epochs : 0.15429
# Loss after 62000 epochs : 0.15419
# Loss after 63000 epochs : 0.15409
# Loss after 64000 epochs : 0.15400
# Loss after 65000 epochs : 0.15392
# Loss after 66000 epochs : 0.15384
# Loss after 67000 epochs : 0.15376
# Loss after 68000 epochs : 0.15369
# Loss after 69000 epochs : 0.15362
# Loss after 70000 epochs : 0.15355
# Loss after 71000 epochs : 0.15349
# Loss after 72000 epochs : 0.15343
# Loss after 73000 epochs : 0.15337
# Loss after 74000 epochs : 0.15331
# Loss after 75000 epochs : 0.15326
# Loss after 76000 epochs : 0.15320
# Loss after 77000 epochs : 0.15315
# Loss after 78000 epochs : 0.15310
# Loss after 79000 epochs : 0.15305
# Loss after 80000 epochs : 0.15300
# Loss after 81000 epochs : 0.15295
# Loss after 82000 epochs : 0.15291
# Loss after 83000 epochs : 0.15286
# Loss after 84000 epochs : 0.15282
# Loss after 85000 epochs : 0.15278
# Loss after 86000 epochs : 0.15273
# Loss after 87000 epochs : 0.15269
# Loss after 88000 epochs : 0.15265
# Loss after 89000 epochs : 0.15261
# Loss after 90000 epochs : 0.15257
# Loss after 91000 epochs : 0.15254
# Loss after 92000 epochs : 0.15250
# Loss after 93000 epochs : 0.15246
# Loss after 94000 epochs : 0.15243
# Loss after 95000 epochs : 0.15239
# Loss after 96000 epochs : 0.15235
# Loss after 97000 epochs : 0.15232
# Loss after 98000 epochs : 0.15228
# Loss after 99000 epochs : 0.15225

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.87375

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.855

# %%
cm = confusion_matrix(y_test, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with 10 neurons in hidden layer

# %%
model  = build_model(10, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.27263
# Loss after  1000 epochs : 0.27861
# Loss after  2000 epochs : 0.27665
# Loss after  3000 epochs : 0.26907
# Loss after  4000 epochs : 0.25810
# Loss after  5000 epochs : 0.24581
# Loss after  6000 epochs : 0.23379
# Loss after  7000 epochs : 0.22296
# Loss after  8000 epochs : 0.21360
# Loss after  9000 epochs : 0.20565
# Loss after 10000 epochs : 0.19886
# Loss after 11000 epochs : 0.19301
# Loss after 12000 epochs : 0.18791
# Loss after 13000 epochs : 0.18340
# Loss after 14000 epochs : 0.17939
# Loss after 15000 epochs : 0.17581
# Loss after 16000 epochs : 0.17260
# Loss after 17000 epochs : 0.16972
# Loss after 18000 epochs : 0.16714
# Loss after 19000 epochs : 0.16484
# Loss after 20000 epochs : 0.16278
# Loss after 21000 epochs : 0.16095
# Loss after 22000 epochs : 0.15932
# Loss after 23000 epochs : 0.15787
# Loss after 24000 epochs : 0.15658
# Loss after 25000 epochs : 0.15544
# Loss after 26000 epochs : 0.15444
# Loss after 27000 epochs : 0.15354
# Loss after 28000 epochs : 0.15275
# Loss after 29000 epochs : 0.15205
# Loss after 30000 epochs : 0.15142
# Loss after 31000 epochs : 0.15086
# Loss after 32000 epochs : 0.15036
# Loss after 33000 epochs : 0.14991
# Loss after 34000 epochs : 0.14951
# Loss after 35000 epochs : 0.14914
# Loss after 36000 epochs : 0.14881
# Loss after 37000 epochs : 0.14850
# Loss after 38000 epochs : 0.14821
# Loss after 39000 epochs : 0.14795
# Loss after 40000 epochs : 0.14770
# Loss after 41000 epochs : 0.14747
# Loss after 42000 epochs : 0.14725
# Loss after 43000 epochs : 0.14704
# Loss after 44000 epochs : 0.14684
# Loss after 45000 epochs : 0.14665
# Loss after 46000 epochs : 0.14646
# Loss after 47000 epochs : 0.14627
# Loss after 48000 epochs : 0.14609
# Loss after 49000 epochs : 0.14591
# Loss after 50000 epochs : 0.14572
# Loss after 51000 epochs : 0.14554
# Loss after 52000 epochs : 0.14536
# Loss after 53000 epochs : 0.14518
# Loss after 54000 epochs : 0.14499
# Loss after 55000 epochs : 0.14481
# Loss after 56000 epochs : 0.14462
# Loss after 57000 epochs : 0.14442
# Loss after 58000 epochs : 0.14422
# Loss after 59000 epochs : 0.14402
# Loss after 60000 epochs : 0.14381
# Loss after 61000 epochs : 0.14360
# Loss after 62000 epochs : 0.14338
# Loss after 63000 epochs : 0.14316
# Loss after 64000 epochs : 0.14293
# Loss after 65000 epochs : 0.14269
# Loss after 66000 epochs : 0.14244
# Loss after 67000 epochs : 0.14219
# Loss after 68000 epochs : 0.14193
# Loss after 69000 epochs : 0.14166
# Loss after 70000 epochs : 0.14139
# Loss after 71000 epochs : 0.14110
# Loss after 72000 epochs : 0.14081
# Loss after 73000 epochs : 0.14051
# Loss after 74000 epochs : 0.14020
# Loss after 75000 epochs : 0.13987
# Loss after 76000 epochs : 0.13954
# Loss after 77000 epochs : 0.13921
# Loss after 78000 epochs : 0.13886
# Loss after 79000 epochs : 0.13849
# Loss after 80000 epochs : 0.13812
# Loss after 81000 epochs : 0.13774
# Loss after 82000 epochs : 0.13735
# Loss after 83000 epochs : 0.13695
# Loss after 84000 epochs : 0.13654
# Loss after 85000 epochs : 0.13612
# Loss after 86000 epochs : 0.13569
# Loss after 87000 epochs : 0.13525
# Loss after 88000 epochs : 0.13479
# Loss after 89000 epochs : 0.13433
# Loss after 90000 epochs : 0.13386
# Loss after 91000 epochs : 0.13338
# Loss after 92000 epochs : 0.13289
# Loss after 93000 epochs : 0.13239
# Loss after 94000 epochs : 0.13188
# Loss after 95000 epochs : 0.13135
# Loss after 96000 epochs : 0.13082
# Loss after 97000 epochs : 0.13029
# Loss after 98000 epochs : 0.12974
# Loss after 99000 epochs : 0.12919

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)
# Out:
# 0.8875

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# # with 50 neurons in hidden layer

# %%
model  = build_model(50, X_train, y_train.reshape(-1,1));
# Out:
# Loss after     0 epochs : 0.19778
# Loss after  1000 epochs : 0.25308
# Loss after  2000 epochs : 0.25006
# Loss after  3000 epochs : 0.23263
# Loss after  4000 epochs : 0.21648
# Loss after  5000 epochs : 0.20364
# Loss after  6000 epochs : 0.19369
# Loss after  7000 epochs : 0.18593
# Loss after  8000 epochs : 0.17979
# Loss after  9000 epochs : 0.17485
# Loss after 10000 epochs : 0.17082
# Loss after 11000 epochs : 0.16749
# Loss after 12000 epochs : 0.16470
# Loss after 13000 epochs : 0.16236
# Loss after 14000 epochs : 0.16037
# Loss after 15000 epochs : 0.15868
# Loss after 16000 epochs : 0.15723
# Loss after 17000 epochs : 0.15597
# Loss after 18000 epochs : 0.15489
# Loss after 19000 epochs : 0.15395
# Loss after 20000 epochs : 0.15313
# Loss after 21000 epochs : 0.15241
# Loss after 22000 epochs : 0.15177
# Loss after 23000 epochs : 0.15121
# Loss after 24000 epochs : 0.15071
# Loss after 25000 epochs : 0.15027
# Loss after 26000 epochs : 0.14987
# Loss after 27000 epochs : 0.14951
# Loss after 28000 epochs : 0.14918

# %%
y_pred = predict(model, X_train)
accuracy_score(y_train, y_pred)

# %%
cm = confusion_matrix(y_train, y_pred)
plost = ConfusionMatrixDisplay(cm, display_labels = [0,1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
y_pred = predict(model, X_test)
accuracy_score(y_test, y_pred)

# %%
plost = ConfusionMatrixDisplay(cm, display_labels = [0, 1])
fig, ax = plt.subplots(figsize = (4,4))

plost.plot(ax = ax, cmap = 'Blues', colorbar = False)
ax.grid(False)

# %%
pd.DataFrame(loss_hist).plot(x= 'epoch', y = 'loss')

# %%
fn_plot_decision_boundry(model, X_train, y_train, X_test, y_test)
