# %%
# !/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# Your Name and PRN:
# - Name: Kumar Ankit
# - PRN : 240840128022
# - Date:

# %% [markdown]
# # Image Processing with Neural Network
# ## Assignment A05
#
# ## Tensor Flow
# - Select number of layers
# - Select node in each of the layers
# - Choose activation function
# - multi-class - Fashion MNIST dataset (all 60000 images)
# - Implement one or more of following to achieve max accuracy.
#     - L1/ L2 Regularization
#     - Dropout
#     - Batch Normalization
#     - Early stopping
# - Save model

# %%
###-----------------
### Import Libraries
###-----------------
import os
import sys
import time
import numpy as np
import pandas as pd
import gc

import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

parent_dir = os.path.abspath('..')
sys.path.insert(0, parent_dir)


from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###-----------------
### Global Variables
###-----------------
inpDir = os.path.join('..', 'input')
outDir = '../output'
modelDir = os.path.join('..', 'model')
subDir = 'fashion_mnist'
altName = 'A04_fashion_vanila'

TEST_SIZE = .2
PATIENCE = 20
LR_FACTOR = .2
LR_PATIENCE = 5

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results
tf.random.set_seed(RANDOM_STATE)

# parameters for Matplotlib
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

CMAP = 'brg' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
###-----------------
### Hyper Parameters
###-----------------

EPOCHS = 3000 # number of epochs
ALPHA = 0.001 # learning rate
BATCH_SIZE = 64 # mini batch size (number of rows)

# %% [markdown]
# ## Load Fashion MNIST dataset

# %% [markdown]
# This guide uses the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen here:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fashion MNIST is intended as a drop-in replacement for the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset—often used as the "Hello, World" of machine learning programs for computer vision. The MNIST dataset contains images of handwritten digits (0, 1, 2, etc.) in a format identical to that of the articles of clothing you'll use here.
#
# This guide uses Fashion MNIST for variety, and because it's a slightly more challenging problem than regular MNIST. Both datasets are relatively small and are used to verify that an algorithm works as expected. They're good starting points to test and debug code.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow. Import and [load the Fashion MNIST data](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/fashion_mnist/load_data) directly from TensorFlow:

# %%
train_filename = os.path.join(inpDir, 'fashion_mnist', 'fashion-mnist_train.csv')
test_filename = os.path.join(inpDir, 'fashion_mnist', 'fashion-mnist_test.csv')

train_df = pd.read_csv(train_filename, header = 0)
test_df = pd.read_csv(test_filename, header = 0)

# %% [markdown]
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
train_df['label'].unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1], dtype=int64)

# %%
train_df.isna().sum().sum() # null value not a problem in images
# Out:
# 0

# %%
#class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

class_names = {0: 'T-shirt/top',1:'Trouser',2:'Pullover',3:'Dress',4:'Coat',
               5:'Sandal', 6: 'Shirt',7: 'Sneaker', 8:'Bag', 9: 'Ankle boot'}

# %%
# sample data plot: display a grid of images from the dataset along with their labels

n_rows = 8 # number of rows to display in the grid
n_cols = 8 # number of columns to display in grid

# randomly sample n_rows * n_cols images from the dataset
plot_df = train_df.sample(n = n_rows*n_cols)

# create a new figure for the grid of images with specified sizes
fig = plt.figure(figsize = (15, 12))

# adjust spacing between subplots to eliminate gaps
fig.subplots_adjust(left = 0, right = 1, bottom = 0, top = 1, hspace = 0.05, wspace = 0.05)

# initialize the subplot index
i = 0

# iterate through each row of teh sampled dataframe

for idx, row in plot_df.iterrows():

    i += 1 # incrimant subplot index

    # reshaping the row values (excluding the first columns) into a 28*28 matirx(image dimensions as given))
    image = row.values[1:].reshape(28,28)

    ax = fig.add_subplot(n_rows, n_cols, (i), xticks = [], yticks = []) # No ticks for a clean plot 

    # display the image on the subplot using a binary colormap
    ax.imshow(image, cmap = plt.cm.binary, interpolation = 'nearest')
    
    # add the numeric label of the image in blue text at a specific possition
    ax.text(2, 4, str(row.iloc[0]), color = 'b', fontsize = 16)

    # add the class nameof the image in red text below the numeric label
    ax.text(2, 25, class_names[row.iloc[0]], color = 'r', fontsize = 16)

# display the entire grid of images
plt.show()

# %% [markdown]
# ### splitting data

# %%
train_df['label'] = pd.to_numeric(train_df['label'], downcast = 'integer')
test_df['label'] = pd.to_numeric(test_df['label'], downcast = 'integer')

# %%
X_train = train_df.drop('label', axis = 1).to_numpy()
X_test = train_df.label

X_train, X_test, y_train, y_test = train_test_split(X_train, X_test, test_size = TEST_SIZE, stratify = X_test, random_state = RANDOM_STATE)

train_shape = X_train.shape

# %%
X_train = X_train / 255.0 # dividing by 255 for scaling

X_test = X_test / 255.0

X_valid = test_df / 255.0

# %%
X_valid = test_df.drop('label', axis = 1)


y_valid = test_df.label

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((48000, 784), (12000, 784), (48000,), (12000,))

# %% [markdown]
# ### converting dataset into tensor

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
valid_ds = tf.data.Dataset.from_tensor_slices((X_valid, y_valid))

# %%
train_shape = X_train.shape
test_shape = X_test.shape
valid_shape = X_valid.shape

# %% [markdown]
# ### shuffle and batch the dataset
# - By chaining these operations (shuffle and batch), the dataset is first shuffled
# - and then divided into batches, making it ready for training.

# %%
train_ds = train_ds.shuffle(buffer_size= train_shape[0]).batch(BATCH_SIZE)
test_ds = test_ds.shuffle(buffer_size= test_shape[0]).batch(BATCH_SIZE)
valid_ds= valid_ds.shuffle(buffer_size = valid_shape[0]).batch(BATCH_SIZE)

# %% [markdown]
# ### Optimise the performance
# - Cache the data to avoid reduntant processing
# - Repeat the dataset for multiple epochs
# - Prefetch data to overlap preprocessing and model execution

# %%
# `prefetch()` improves performance by preparing data for the next batch whike the model is still training on the current batch. 
# It essentially overlaps the proces of data loading with model training.
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
valid_ds = valid_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
del train_df, test_df # to save memory we can delete unwanted dataFrames
gc.collect()
gc.collect()
# This is because certain objects might become unreachable only after other objects are deleted during the first collection.
# A second pass ensures that such "indirectly" orphaned objects are also handled.
# Out:
# 0

# %% [markdown]
# # prepare model

# %% [markdown]
# #### functional api
# - 784/2 = 392
# - 392/2 = 196
# - 196/2 = 96
# - 96/2 = 48

# %%
initializer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE) # weight initializer for a neural network layer in TensorFlow/Keras using the Glorot Uniform Initialization


## definin gregularizer

regularizer = tf.keras.regularizers.L2(.05) # tune reg lambda

# %% [markdown]
# ## using dropout

# %%
inputs = tf.keras.Input(shape = (train_shape[1], ), name = 'input')
DOR1 = 0.2

DOR2 = .3 # drop out rate i.e 30  % of the neuron's weight will be neglected"

x = tf.keras.layers.Dense(196,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name= 'fc_1')(inputs)

# x = tf.keras.layers.BatchNormalization()(x) # batch normalization because the normalizatin of the input does'nt pass on to the hidden layers

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR1)(x)

x = tf.keras.layers.Dense(49,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name = 'fc_2')(x) # it can be understood like a linked list

# x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR2)(x)


outputs = tf.keras.layers.Dense(10 ,
                                kernel_initializer = initializer, name= 'output')(x)
model = tf.keras.Model(inputs = inputs, outputs = outputs, name = 'MINST')

# %%
model.summary()
# Out:
# Model: "MINST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_1 (Dense)                    │ (None, 196)            │       153,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 196)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 196)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_2 (Dense)                    │ (None, 49)             │         9,653 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 49)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 49)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 164,013 (640.68 KB)
#  Trainable params: 164,013 (640.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model.compile(optimizer = optimizer, loss= loss_fn, metrics = ['accuracy'])

# %%
history = model.fit(train_ds, validation_data= test_ds, epochs = EPOCHS, verbose = 2)
# Out:
# Epoch 1/3000
# 750/750 - 7s - 9ms/step - accuracy: 0.7665 - loss: 0.6638 - val_accuracy: 0.8420 - val_loss: 0.4362
# Epoch 2/3000
# 750/750 - 4s - 6ms/step - accuracy: 0.8383 - loss: 0.4598 - val_accuracy: 0.8572 - val_loss: 0.3970
# Epoch 3/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8519 - loss: 0.4194 - val_accuracy: 0.8647 - val_loss: 0.3715
# Epoch 4/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8612 - loss: 0.3897 - val_accuracy: 0.8690 - val_loss: 0.3645
# Epoch 5/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8667 - loss: 0.3700 - val_accuracy: 0.8742 - val_loss: 0.3531
# Epoch 6/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8722 - loss: 0.3576 - val_accuracy: 0.8723 - val_loss: 0.3460
# Epoch 7/3000
# 750/750 - 6s - 8ms/step - accuracy: 0.8758 - loss: 0.3438 - val_accuracy: 0.8802 - val_loss: 0.3349
# Epoch 8/3000
# 750/750 - 5s - 6ms/step - accuracy: 0.8781 - loss: 0.3358 - val_accuracy: 0.8802 - val_loss: 0.3343
# Epoch 9/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8822 - loss: 0.3251 - val_accuracy: 0.8853 - val_loss: 0.3225
# Epoch 10/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8849 - loss: 0.3151 - val_accuracy: 0.8836 - val_loss: 0.3204
# Epoch 11/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8873 - loss: 0.3074 - val_accuracy: 0.8856 - val_loss: 0.3292
# Epoch 12/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8896 - loss: 0.3009 - val_accuracy: 0.8816 - val_loss: 0.3318
# Epoch 13/3000
# 750/750 - 6s - 7ms/step - accuracy: 0.8903 - loss: 0.2961 - val_accuracy: 0.8864 - val_loss: 0.3285
# Epoch 14/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8926 - loss: 0.2911 - val_accuracy: 0.8869 - val_loss: 0.3212
# Epoch 15/3000
# 750/750 - 5s - 6ms/step - accuracy: 0.8931 - loss: 0.2891 - val_accuracy: 0.8825 - val_loss: 0.3345
# Epoch 16/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8942 - loss: 0.2813 - val_accuracy: 0.8879 - val_loss: 0.3258
# Epoch 17/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.8970 - loss: 0.2771 - val_accuracy: 0.8898 - val_loss: 0.3195
# Epoch 18/3000
# 750/750 - 5s - 6ms/step - accuracy: 0.8989 - loss: 0.2748 - val_accuracy: 0.8873 - val_loss: 0.3186
# Epoch 19/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9009 - loss: 0.2690 - val_accuracy: 0.8907 - val_loss: 0.3158
# Epoch 20/3000
# 750/750 - 4s - 6ms/step - accuracy: 0.9011 - loss: 0.2662 - val_accuracy: 0.8848 - val_loss: 0.3335
# Epoch 21/3000
# 750/750 - 4s - 5ms/step - accuracy: 0.9032 - loss: 0.2613 - val_accuracy: 0.8911 - val_loss: 0.3214
# Epoch 22/3000
# 750/750 - 4s - 5ms/step - accuracy: 0.9047 - loss: 0.2561 - val_accuracy: 0.8922 - val_loss: 0.3208
# Epoch 23/3000
# 750/750 - 4s - 6ms/step - accuracy: 0.9043 - loss: 0.2582 - val_accuracy: 0.8929 - val_loss: 0.3146
# Epoch 24/3000
# 750/750 - 5s - 6ms/step - accuracy: 0.9056 - loss: 0.2488 - val_accuracy: 0.8875 - val_loss: 0.3358
# Epoch 25/3000
# 750/750 - 5s - 6ms/step - accuracy: 0.9054 - loss: 0.2486 - val_accuracy: 0.8902 - val_loss: 0.3190
# Epoch 26/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9068 - loss: 0.2448 - val_accuracy: 0.8894 - val_loss: 0.3307
# Epoch 27/3000
# 750/750 - 5s - 6ms/step - accuracy: 0.9090 - loss: 0.2428 - val_accuracy: 0.8860 - val_loss: 0.3371
# Epoch 28/3000
# 750/750 - 4s - 5ms/step - accuracy: 0.9083 - loss: 0.2409 - val_accuracy: 0.8902 - val_loss: 0.3218
# Epoch 29/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9100 - loss: 0.2376 - val_accuracy: 0.8887 - val_loss: 0.3233
# Epoch 30/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9111 - loss: 0.2365 - val_accuracy: 0.8931 - val_loss: 0.3298
# Epoch 31/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9106 - loss: 0.2330 - val_accuracy: 0.8903 - val_loss: 0.3281
# Epoch 32/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9129 - loss: 0.2320 - val_accuracy: 0.8924 - val_loss: 0.3238
# Epoch 33/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9135 - loss: 0.2279 - val_accuracy: 0.8913 - val_loss: 0.3340
# Epoch 34/3000
# 750/750 - 5s - 7ms/step - accuracy: 0.9134 - loss: 0.2247 - val_accuracy: 0.8873 - val_loss: 0.3464
# Epoch 35/3000
# 750/750 - 4s - 6ms/step - accuracy: 0.9161 - loss: 0.2223 - val_accuracy: 0.8924 - val_loss: 0.3368
# Epoch 36/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 history = model.fit(train_ds, validation_data= test_ds, epochs = EPOCHS, verbose = 2)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
hist_df = pd.DataFrame(history.history)

# %%
fn_plot_tf_hist(hist_df=hist_df)

# %% [raw]
# - our job is to bring loss curve of both train and test as close as possible to each other as possible

# %% [markdown]
# # ModelCheckpoint

# %%
inputs = tf.keras.Input(shape = (train_shape[1], ), name = 'input')
DOR1 = 0.2

DOR2 = .3 # drop out rate i.e 30  % of the neuron's weight will be neglected"

DOR3 = .4

x = tf.keras.layers.Dense(196,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name= 'fc_1')(inputs)

# x = tf.keras.layers.BatchNormalization()(x) # batch normalization because the normalizatin of the input does'nt pass on to the hidden layers

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR1)(x)

x = tf.keras.layers.Dense(98,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name = 'fc_2')(x) # it can be understood like a linked list

# x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR2)(x)

x = tf.keras.layers.Dense(49,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name = 'fc_3')(x) # it can be understood like a linked list

# x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR3)(x)


outputs = tf.keras.layers.Dense(10 ,
                                kernel_initializer = initializer, name= 'output')(x)
model1 = tf.keras.Model(inputs = inputs, outputs = outputs, name = 'MINST')

# %% [markdown]
# ## ModelCheckpoint
# - Saves the model to the specified path (`chckptPath`) whenever there’s an improvement in the monitored metric (val_loss in this case).
# - `save_best_only=True` ensures that only the model with the best validation loss is saved, avoiding unnecessary storage of suboptimal models.
#
# **EarlyStopping Callback**
#
# - Stops training early when the monitored metric (val_loss) stops improving for a defined number of epochs (specified by patience).
# - `restore_best_weights=True` ensures that the model's weights are restored to their best state before stopping.
#
# **ReduceLROnPlateau Callback**
#
# - Monitors the validation loss (val_loss) and reduces the learning rate when it stops improving for a defined number of epochs (specified by `LR_PATIENCE`).
# - `factor=LR_FACTOR` determines how much the learning rate is reduced. For example, if factor=0.1, the learning rate is reduced to 10% of its current value.

# %%
chkptPath = os.path.join(modelDir, subDir, 'all_in.keras')
chkpt_cb= tf.keras.callbacks.ModelCheckpoint(chkptPath,
                                             monitor = 'val_loss',
                                             verbose =2,
                                             save_best_only= True)

es_cb = tf.keras.callbacks.EarlyStopping(monitor= 'val_loss',
                                        verbose=2,
                                        patience = PATIENCE,
                                        restore_best_weights= True)

lr_cb= tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                            factor=LR_FACTOR,
                                            patience= LR_PATIENCE,
                                            verbose=2)

# %%
model1.summary()
# Out:
# Model: "MINST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_1 (Dense)                    │ (None, 196)            │       153,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 196)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 196)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_2 (Dense)                    │ (None, 98)             │        19,306 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 98)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 98)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_3 (Dense)                    │ (None, 49)             │         4,851 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 49)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 49)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,517 (697.33 KB)
#  Trainable params: 178,517 (697.33 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model1.compile(optimizer = optimizer, loss= loss_fn, metrics = ['accuracy'])

# %%
history = model1.fit(train_ds, validation_data= test_ds, epochs = EPOCHS, verbose = 2, callbacks = [chkpt_cb, es_cb, lr_cb])
# Out:
# Epoch 1/3000
#
# Epoch 1: val_loss improved from inf to 0.45248, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 10ms/step - accuracy: 0.7281 - loss: 0.7766 - val_accuracy: 0.8356 - val_loss: 0.4525 - learning_rate: 0.0010
# Epoch 2/3000
#
# Epoch 2: val_loss improved from 0.45248 to 0.43559, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 5s - 7ms/step - accuracy: 0.8240 - loss: 0.5071 - val_accuracy: 0.8404 - val_loss: 0.4356 - learning_rate: 0.0010
# Epoch 3/3000
#
# Epoch 3: val_loss improved from 0.43559 to 0.38944, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.8411 - loss: 0.4567 - val_accuracy: 0.8570 - val_loss: 0.3894 - learning_rate: 0.0010
# Epoch 4/3000
#
# Epoch 4: val_loss improved from 0.38944 to 0.38777, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 5s - 7ms/step - accuracy: 0.8501 - loss: 0.4302 - val_accuracy: 0.8611 - val_loss: 0.3878 - learning_rate: 0.0010
# Epoch 5/3000
#
# Epoch 5: val_loss improved from 0.38777 to 0.36552, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 9ms/step - accuracy: 0.8579 - loss: 0.4063 - val_accuracy: 0.8677 - val_loss: 0.3655 - learning_rate: 0.0010
# Epoch 6/3000
#
# Epoch 6: val_loss improved from 0.36552 to 0.35957, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 9ms/step - accuracy: 0.8612 - loss: 0.3937 - val_accuracy: 0.8707 - val_loss: 0.3596 - learning_rate: 0.0010
# Epoch 7/3000
#
# Epoch 7: val_loss improved from 0.35957 to 0.34723, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.8683 - loss: 0.3748 - val_accuracy: 0.8751 - val_loss: 0.3472 - learning_rate: 0.0010
# Epoch 8/3000
#
# Epoch 8: val_loss improved from 0.34723 to 0.34659, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 9ms/step - accuracy: 0.8716 - loss: 0.3676 - val_accuracy: 0.8762 - val_loss: 0.3466 - learning_rate: 0.0010
# Epoch 9/3000
#
# Epoch 9: val_loss did not improve from 0.34659
# 750/750 - 6s - 8ms/step - accuracy: 0.8744 - loss: 0.3554 - val_accuracy: 0.8721 - val_loss: 0.3633 - learning_rate: 0.0010
# Epoch 10/3000
#
# Epoch 10: val_loss improved from 0.34659 to 0.33249, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 9ms/step - accuracy: 0.8766 - loss: 0.3467 - val_accuracy: 0.8810 - val_loss: 0.3325 - learning_rate: 0.0010
# Epoch 11/3000
#
# Epoch 11: val_loss did not improve from 0.33249
# 750/750 - 6s - 8ms/step - accuracy: 0.8793 - loss: 0.3410 - val_accuracy: 0.8813 - val_loss: 0.3365 - learning_rate: 0.0010
# Epoch 12/3000
#
# Epoch 12: val_loss did not improve from 0.33249
# 750/750 - 5s - 7ms/step - accuracy: 0.8819 - loss: 0.3339 - val_accuracy: 0.8802 - val_loss: 0.3402 - learning_rate: 0.0010
# Epoch 13/3000
#
# Epoch 13: val_loss did not improve from 0.33249
# 750/750 - 6s - 9ms/step - accuracy: 0.8822 - loss: 0.3293 - val_accuracy: 0.8817 - val_loss: 0.3353 - learning_rate: 0.0010
# Epoch 14/3000
#
# Epoch 14: val_loss did not improve from 0.33249
# 750/750 - 6s - 8ms/step - accuracy: 0.8847 - loss: 0.3230 - val_accuracy: 0.8805 - val_loss: 0.3460 - learning_rate: 0.0010
# Epoch 15/3000
#
# Epoch 15: val_loss improved from 0.33249 to 0.32897, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 5s - 7ms/step - accuracy: 0.8882 - loss: 0.3139 - val_accuracy: 0.8838 - val_loss: 0.3290 - learning_rate: 0.0010
# Epoch 16/3000
#
# Epoch 16: val_loss did not improve from 0.32897
# 750/750 - 6s - 9ms/step - accuracy: 0.8892 - loss: 0.3097 - val_accuracy: 0.8820 - val_loss: 0.3327 - learning_rate: 0.0010
# Epoch 17/3000
#
# Epoch 17: val_loss improved from 0.32897 to 0.32514, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.8902 - loss: 0.3055 - val_accuracy: 0.8873 - val_loss: 0.3251 - learning_rate: 0.0010
# Epoch 18/3000
#
# Epoch 18: val_loss did not improve from 0.32514
# 750/750 - 6s - 8ms/step - accuracy: 0.8927 - loss: 0.3016 - val_accuracy: 0.8839 - val_loss: 0.3339 - learning_rate: 0.0010
# Epoch 19/3000
#
# Epoch 19: val_loss did not improve from 0.32514
# 750/750 - 6s - 8ms/step - accuracy: 0.8938 - loss: 0.2965 - val_accuracy: 0.8864 - val_loss: 0.3313 - learning_rate: 0.0010
# Epoch 20/3000
#
# Epoch 20: val_loss improved from 0.32514 to 0.32129, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.8928 - loss: 0.3005 - val_accuracy: 0.8880 - val_loss: 0.3213 - learning_rate: 0.0010
# Epoch 21/3000
#
# Epoch 21: val_loss did not improve from 0.32129
# 750/750 - 6s - 8ms/step - accuracy: 0.8947 - loss: 0.2921 - val_accuracy: 0.8855 - val_loss: 0.3265 - learning_rate: 0.0010
# Epoch 22/3000
#
# Epoch 22: val_loss did not improve from 0.32129
# 750/750 - 6s - 8ms/step - accuracy: 0.8963 - loss: 0.2914 - val_accuracy: 0.8796 - val_loss: 0.3400 - learning_rate: 0.0010
# Epoch 23/3000
#
# Epoch 23: val_loss did not improve from 0.32129
# 750/750 - 6s - 8ms/step - accuracy: 0.8989 - loss: 0.2815 - val_accuracy: 0.8855 - val_loss: 0.3336 - learning_rate: 0.0010
# Epoch 24/3000
#
# Epoch 24: val_loss did not improve from 0.32129
# 750/750 - 6s - 9ms/step - accuracy: 0.8966 - loss: 0.2837 - val_accuracy: 0.8842 - val_loss: 0.3327 - learning_rate: 0.0010
# Epoch 25/3000
#
# Epoch 25: val_loss did not improve from 0.32129
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 750/750 - 6s - 8ms/step - accuracy: 0.8990 - loss: 0.2809 - val_accuracy: 0.8852 - val_loss: 0.3374 - learning_rate: 0.0010
# Epoch 26/3000
#
# Epoch 26: val_loss improved from 0.32129 to 0.32128, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 9ms/step - accuracy: 0.9112 - loss: 0.2490 - val_accuracy: 0.8924 - val_loss: 0.3213 - learning_rate: 2.0000e-04
# Epoch 27/3000
#
# Epoch 27: val_loss improved from 0.32128 to 0.31722, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.9146 - loss: 0.2383 - val_accuracy: 0.8937 - val_loss: 0.3172 - learning_rate: 2.0000e-04
# Epoch 28/3000
#
# Epoch 28: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9145 - loss: 0.2325 - val_accuracy: 0.8943 - val_loss: 0.3189 - learning_rate: 2.0000e-04
# Epoch 29/3000
#
# Epoch 29: val_loss did not improve from 0.31722
# 750/750 - 6s - 9ms/step - accuracy: 0.9155 - loss: 0.2326 - val_accuracy: 0.8938 - val_loss: 0.3206 - learning_rate: 2.0000e-04
# Epoch 30/3000
#
# Epoch 30: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9171 - loss: 0.2291 - val_accuracy: 0.8949 - val_loss: 0.3243 - learning_rate: 2.0000e-04
# Epoch 31/3000
#
# Epoch 31: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9184 - loss: 0.2250 - val_accuracy: 0.8928 - val_loss: 0.3316 - learning_rate: 2.0000e-04
# Epoch 32/3000
#
# Epoch 32: val_loss did not improve from 0.31722
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 750/750 - 6s - 8ms/step - accuracy: 0.9173 - loss: 0.2248 - val_accuracy: 0.8927 - val_loss: 0.3296 - learning_rate: 2.0000e-04
# Epoch 33/3000
#
# Epoch 33: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9200 - loss: 0.2184 - val_accuracy: 0.8932 - val_loss: 0.3274 - learning_rate: 4.0000e-05
# Epoch 34/3000
#
# Epoch 34: val_loss did not improve from 0.31722
# 750/750 - 6s - 9ms/step - accuracy: 0.9233 - loss: 0.2147 - val_accuracy: 0.8948 - val_loss: 0.3292 - learning_rate: 4.0000e-05
# Epoch 35/3000
#
# Epoch 35: val_loss did not improve from 0.31722
# 750/750 - 6s - 7ms/step - accuracy: 0.9218 - loss: 0.2145 - val_accuracy: 0.8947 - val_loss: 0.3294 - learning_rate: 4.0000e-05
# Epoch 36/3000
#
# Epoch 36: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9223 - loss: 0.2153 - val_accuracy: 0.8951 - val_loss: 0.3276 - learning_rate: 4.0000e-05
# Epoch 37/3000
#
# Epoch 37: val_loss did not improve from 0.31722
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 750/750 - 6s - 9ms/step - accuracy: 0.9212 - loss: 0.2115 - val_accuracy: 0.8954 - val_loss: 0.3255 - learning_rate: 4.0000e-05
# Epoch 38/3000
#
# Epoch 38: val_loss did not improve from 0.31722
# 750/750 - 5s - 7ms/step - accuracy: 0.9226 - loss: 0.2139 - val_accuracy: 0.8958 - val_loss: 0.3252 - learning_rate: 8.0000e-06
# Epoch 39/3000
#
# Epoch 39: val_loss did not improve from 0.31722
# 750/750 - 7s - 9ms/step - accuracy: 0.9248 - loss: 0.2103 - val_accuracy: 0.8953 - val_loss: 0.3250 - learning_rate: 8.0000e-06
# Epoch 40/3000
#
# Epoch 40: val_loss did not improve from 0.31722
# 750/750 - 6s - 9ms/step - accuracy: 0.9229 - loss: 0.2107 - val_accuracy: 0.8950 - val_loss: 0.3260 - learning_rate: 8.0000e-06
# Epoch 41/3000
#
# Epoch 41: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9235 - loss: 0.2121 - val_accuracy: 0.8952 - val_loss: 0.3265 - learning_rate: 8.0000e-06
# Epoch 42/3000
#
# Epoch 42: val_loss did not improve from 0.31722
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 750/750 - 6s - 8ms/step - accuracy: 0.9246 - loss: 0.2089 - val_accuracy: 0.8947 - val_loss: 0.3268 - learning_rate: 8.0000e-06
# Epoch 43/3000
#
# Epoch 43: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9235 - loss: 0.2121 - val_accuracy: 0.8944 - val_loss: 0.3265 - learning_rate: 1.6000e-06
# Epoch 44/3000
#
# Epoch 44: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9234 - loss: 0.2103 - val_accuracy: 0.8953 - val_loss: 0.3265 - learning_rate: 1.6000e-06
# Epoch 45/3000
#
# Epoch 45: val_loss did not improve from 0.31722
# 750/750 - 7s - 9ms/step - accuracy: 0.9246 - loss: 0.2096 - val_accuracy: 0.8953 - val_loss: 0.3264 - learning_rate: 1.6000e-06
# Epoch 46/3000
#
# Epoch 46: val_loss did not improve from 0.31722
# 750/750 - 6s - 8ms/step - accuracy: 0.9233 - loss: 0.2118 - val_accuracy: 0.8953 - val_loss: 0.3264 - learning_rate: 1.6000e-06
# Epoch 47/3000
#
# Epoch 47: val_loss did not improve from 0.31722
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 750/750 - 6s - 8ms/step - accuracy: 0.9224 - loss: 0.2100 - val_accuracy: 0.8950 - val_loss: 0.3265 - learning_rate: 1.6000e-06
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 27.

# %%
hist_df = pd.DataFrame(history.history)
fn_plot_tf_hist(hist_df=hist_df)

# %%
import pickle
