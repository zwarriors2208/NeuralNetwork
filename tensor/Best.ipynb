# %%
# !/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# Your Name and PRN:
# - Name: Kumar Ankit
# - PRN : 240840128022
# - Date:

# %% [markdown]
# # Image Processing with Neural Network
# ## Assignment A05
#
# ## Tensor Flow
# - Select number of layers
# - Select node in each of the layers
# - Choose activation function
# - multi-class - Fashion MNIST dataset (all 60000 images)
# - Implement one or more of following to achieve max accuracy.
#     - L1/ L2 Regularization
#     - Dropout
#     - Batch Normalization
#     - Early stopping
# - Save model

# %%
###-----------------
### Import Libraries
###-----------------
import os
import sys
import time
import numpy as np
import pandas as pd
import gc

import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

parent_dir = os.path.abspath('..')
sys.path.insert(0, parent_dir)


from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###-----------------
### Global Variables
###-----------------
inpDir = os.path.join('..', 'input')
outDir = '../output'
modelDir = os.path.join('..', 'model')
subDir = 'fashion_mnist'
altName = 'A04_fashion_vanila'

TEST_SIZE = .2
PATIENCE = 20
LR_FACTOR = .2
LR_PATIENCE = 5

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results
tf.random.set_seed(RANDOM_STATE)

# parameters for Matplotlib
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

CMAP = 'brg' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
###-----------------
### Hyper Parameters
###-----------------

EPOCHS = 2000 # number of epochs
ALPHA = 0.001 # learning rate
BATCH_SIZE = 64 # mini batch size (number of rows)

# %% [markdown]
# ## Load Fashion MNIST dataset

# %% [markdown]
# This guide uses the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen here:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fashion MNIST is intended as a drop-in replacement for the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset—often used as the "Hello, World" of machine learning programs for computer vision. The MNIST dataset contains images of handwritten digits (0, 1, 2, etc.) in a format identical to that of the articles of clothing you'll use here.
#
# This guide uses Fashion MNIST for variety, and because it's a slightly more challenging problem than regular MNIST. Both datasets are relatively small and are used to verify that an algorithm works as expected. They're good starting points to test and debug code.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow. Import and [load the Fashion MNIST data](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/fashion_mnist/load_data) directly from TensorFlow:

# %%
train_filename = os.path.join(inpDir, 'fashion_mnist', 'fashion-mnist_train.csv')
test_filename = os.path.join(inpDir, 'fashion_mnist', 'fashion-mnist_test.csv')

train_df = pd.read_csv(train_filename, header = 0)
test_df = pd.read_csv(test_filename, header = 0)

# %% [markdown]
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
train_df['label'].unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1], dtype=int64)

# %%
train_df.isna().sum().sum() # null value not a problem in images
# Out:
# 0

# %%
#class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

class_names = {0: 'T-shirt/top',1:'Trouser',2:'Pullover',3:'Dress',4:'Coat',
               5:'Sandal', 6: 'Shirt',7: 'Sneaker', 8:'Bag', 9: 'Ankle boot'}

# %%
# sample data plot: display a grid of images from the dataset along with their labels

n_rows = 8 # number of rows to display in the grid
n_cols = 8 # number of columns to display in grid

# randomly sample n_rows * n_cols images from the dataset
plot_df = train_df.sample(n = n_rows*n_cols)

# create a new figure for the grid of images with specified sizes
fig = plt.figure(figsize = (15, 12))

# adjust spacing between subplots to eliminate gaps
fig.subplots_adjust(left = 0, right = 1, bottom = 0, top = 1, hspace = 0.05, wspace = 0.05)

# initialize the subplot index
i = 0

# iterate through each row of teh sampled dataframe

for idx, row in plot_df.iterrows():

    i += 1 # incrimant subplot index

    # reshaping the row values (excluding the first columns) into a 28*28 matirx(image dimensions as given))
    image = row.values[1:].reshape(28,28)

    ax = fig.add_subplot(n_rows, n_cols, (i), xticks = [], yticks = []) # No ticks for a clean plot 

    # display the image on the subplot using a binary colormap
    ax.imshow(image, cmap = plt.cm.binary, interpolation = 'nearest')
    
    # add the numeric label of the image in blue text at a specific possition
    ax.text(2, 4, str(row.iloc[0]), color = 'b', fontsize = 16)

    # add the class nameof the image in red text below the numeric label
    ax.text(2, 25, class_names[row.iloc[0]], color = 'r', fontsize = 16)

# display the entire grid of images
plt.show()

# %% [markdown]
# ### splitting data

# %%
train_df['label'] = pd.to_numeric(train_df['label'], downcast = 'integer')
test_df['label'] = pd.to_numeric(test_df['label'], downcast = 'integer')

# %%
X_train = train_df.drop('label', axis = 1).to_numpy()
X_test = train_df.label

X_train, X_test, y_train, y_test = train_test_split(X_train, X_test, test_size = TEST_SIZE, stratify = X_test, random_state = RANDOM_STATE)

train_shape = X_train.shape

# %%
X_train = X_train / 255.0 # dividing by 255 for scaling

X_test = X_test / 255.0

X_valid = test_df / 255.0

# %%
X_valid = test_df.drop('label', axis = 1)


y_valid = test_df.label

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((48000, 784), (12000, 784), (48000,), (12000,))

# %% [markdown]
# ### converting dataset into tensor

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
valid_ds = tf.data.Dataset.from_tensor_slices((X_valid, y_valid))

# %%
train_shape = X_train.shape
test_shape = X_test.shape
valid_shape = X_valid.shape

# %% [markdown]
# ### shuffle and batch the dataset
# - By chaining these operations (shuffle and batch), the dataset is first shuffled
# - and then divided into batches, making it ready for training.

# %%
train_ds = train_ds.shuffle(buffer_size= train_shape[0]).batch(BATCH_SIZE)
test_ds = test_ds.shuffle(buffer_size= test_shape[0]).batch(BATCH_SIZE)
valid_ds= valid_ds.shuffle(buffer_size = valid_shape[0]).batch(BATCH_SIZE)

# %% [markdown]
# ### Optimise the performance
# - Cache the data to avoid reduntant processing
# - Repeat the dataset for multiple epochs
# - Prefetch data to overlap preprocessing and model execution

# %%
# `prefetch()` improves performance by preparing data for the next batch whike the model is still training on the current batch. 
# It essentially overlaps the proces of data loading with model training.
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
valid_ds = valid_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
del train_df, test_df # to save memory we can delete unwanted dataFrames
gc.collect()
gc.collect()
# This is because certain objects might become unreachable only after other objects are deleted during the first collection.
# A second pass ensures that such "indirectly" orphaned objects are also handled.
# Out:
# 0

# %% [markdown]
# # prepare model

# %% [markdown]
# #### functional api
# - 784/2 = 392
# - 392/2 = 196
# - 196/2 = 96
# - 96/2 = 48

# %% [markdown]
# # best

# %%
initializer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

# %%
inputs = tf.keras.Input(shape = (train_shape[1], ), name = 'input')
DOR1 = 0.2

DOR2 = .3 # drop out rate i.e 30  % of the neuron's weight will be neglected"

DOR3 = .4

x = tf.keras.layers.Dense(196,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name= 'fc_1')(inputs)

x = tf.keras.layers.BatchNormalization()(x) # batch normalization because the normalizatin of the input does'nt pass on to the hidden layers

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR1)(x)

x = tf.keras.layers.Dense(98,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name = 'fc_2')(x) # it can be understood like a linked list

x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR2)(x)

x = tf.keras.layers.Dense(49,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name = 'fc_3')(x) # it can be understood like a linked list

x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Activation(activation = 'relu')(x)

x = tf.keras.layers.Dropout(rate = DOR3)(x)


outputs = tf.keras.layers.Dense(10 ,
                                kernel_initializer = initializer, name= 'output')(x)
model1 = tf.keras.Model(inputs = inputs, outputs = outputs, name = 'MINST')

# %% [markdown]
# ## using batch normalization and dropout together

# %%
chkptPath = os.path.join(modelDir, subDir, 'all_in.keras')
chkpt_cb= tf.keras.callbacks.ModelCheckpoint(chkptPath,
                                             monitor = 'val_accuracy',
                                             verbose =2,
                                             save_best_only= True)

es_cb = tf.keras.callbacks.EarlyStopping(monitor= 'val_accuracy',
                                        verbose=2,
                                        patience = PATIENCE,
                                        restore_best_weights= True)

lr_cb= tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',
                                            factor=LR_FACTOR,
                                            patience= LR_PATIENCE,
                                            verbose=2)

# %%
model1.summary()
# Out:
# Model: "MINST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_1 (Dense)                    │ (None, 196)            │       153,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 196)            │           784 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 196)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 196)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_2 (Dense)                    │ (None, 98)             │        19,306 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 98)             │           392 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 98)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 98)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_3 (Dense)                    │ (None, 49)             │         4,851 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 49)             │           196 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 49)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 49)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 179,889 (702.69 KB)
#  Trainable params: 179,203 (700.01 KB)
#  Non-trainable params: 686 (2.68 KB)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model1.compile(optimizer = optimizer, loss= loss_fn, metrics = ['accuracy'])

# %%
history = model1.fit(train_ds, validation_data= test_ds, epochs = EPOCHS, verbose = 2, callbacks = [chkpt_cb, es_cb, lr_cb])
# Out:
# Epoch 1/2000
#
# Epoch 1: val_accuracy improved from -inf to 0.83667, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 11s - 15ms/step - accuracy: 0.7520 - loss: 0.7528 - val_accuracy: 0.8367 - val_loss: 0.4440 - learning_rate: 0.0010
# Epoch 2/2000
#
# Epoch 2: val_accuracy improved from 0.83667 to 0.85525, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 9ms/step - accuracy: 0.8271 - loss: 0.5155 - val_accuracy: 0.8553 - val_loss: 0.3949 - learning_rate: 0.0010
# Epoch 3/2000
#
# Epoch 3: val_accuracy improved from 0.85525 to 0.86592, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 8s - 10ms/step - accuracy: 0.8435 - loss: 0.4634 - val_accuracy: 0.8659 - val_loss: 0.3713 - learning_rate: 0.0010
# Epoch 4/2000
#
# Epoch 4: val_accuracy improved from 0.86592 to 0.86875, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 9ms/step - accuracy: 0.8558 - loss: 0.4255 - val_accuracy: 0.8687 - val_loss: 0.3640 - learning_rate: 0.0010
# Epoch 5/2000
#
# Epoch 5: val_accuracy improved from 0.86875 to 0.87050, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 10ms/step - accuracy: 0.8609 - loss: 0.4034 - val_accuracy: 0.8705 - val_loss: 0.3531 - learning_rate: 0.0010
# Epoch 6/2000
#
# Epoch 6: val_accuracy improved from 0.87050 to 0.87875, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 10ms/step - accuracy: 0.8692 - loss: 0.3816 - val_accuracy: 0.8788 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 7/2000
#
# Epoch 7: val_accuracy did not improve from 0.87875
# 750/750 - 6s - 8ms/step - accuracy: 0.8748 - loss: 0.3680 - val_accuracy: 0.8737 - val_loss: 0.3445 - learning_rate: 0.0010
# Epoch 8/2000
#
# Epoch 8: val_accuracy did not improve from 0.87875
# 750/750 - 7s - 9ms/step - accuracy: 0.8783 - loss: 0.3500 - val_accuracy: 0.8772 - val_loss: 0.3348 - learning_rate: 0.0010
# Epoch 9/2000
#
# Epoch 9: val_accuracy improved from 0.87875 to 0.88092, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.8830 - loss: 0.3387 - val_accuracy: 0.8809 - val_loss: 0.3304 - learning_rate: 0.0010
# Epoch 10/2000
#
# Epoch 10: val_accuracy did not improve from 0.88092
# 750/750 - 7s - 10ms/step - accuracy: 0.8850 - loss: 0.3302 - val_accuracy: 0.8795 - val_loss: 0.3433 - learning_rate: 0.0010
# Epoch 11/2000
#
# Epoch 11: val_accuracy did not improve from 0.88092
# 750/750 - 7s - 10ms/step - accuracy: 0.8887 - loss: 0.3162 - val_accuracy: 0.8715 - val_loss: 0.3549 - learning_rate: 0.0010
# Epoch 12/2000
#
# Epoch 12: val_accuracy did not improve from 0.88092
# 750/750 - 8s - 10ms/step - accuracy: 0.8925 - loss: 0.3070 - val_accuracy: 0.8784 - val_loss: 0.3285 - learning_rate: 0.0010
# Epoch 13/2000
#
# Epoch 13: val_accuracy did not improve from 0.88092
# 750/750 - 8s - 10ms/step - accuracy: 0.8947 - loss: 0.2992 - val_accuracy: 0.8794 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 14/2000
#
# Epoch 14: val_accuracy improved from 0.88092 to 0.88125, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 10ms/step - accuracy: 0.8985 - loss: 0.2893 - val_accuracy: 0.8813 - val_loss: 0.3243 - learning_rate: 0.0010
# Epoch 15/2000
#
# Epoch 15: val_accuracy improved from 0.88125 to 0.88508, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 8s - 10ms/step - accuracy: 0.9015 - loss: 0.2815 - val_accuracy: 0.8851 - val_loss: 0.3292 - learning_rate: 0.0010
# Epoch 16/2000
#
# Epoch 16: val_accuracy did not improve from 0.88508
# 750/750 - 7s - 9ms/step - accuracy: 0.9035 - loss: 0.2767 - val_accuracy: 0.8792 - val_loss: 0.3392 - learning_rate: 0.0010
# Epoch 17/2000
#
# Epoch 17: val_accuracy did not improve from 0.88508
# 750/750 - 8s - 10ms/step - accuracy: 0.9030 - loss: 0.2701 - val_accuracy: 0.8773 - val_loss: 0.3361 - learning_rate: 0.0010
# Epoch 18/2000
#
# Epoch 18: val_accuracy did not improve from 0.88508
# 750/750 - 7s - 9ms/step - accuracy: 0.9082 - loss: 0.2613 - val_accuracy: 0.8777 - val_loss: 0.3539 - learning_rate: 0.0010
# Epoch 19/2000
#
# Epoch 19: val_accuracy improved from 0.88508 to 0.88625, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 8s - 10ms/step - accuracy: 0.9101 - loss: 0.2537 - val_accuracy: 0.8863 - val_loss: 0.3326 - learning_rate: 0.0010
# Epoch 20/2000
#
# Epoch 20: val_accuracy did not improve from 0.88625
# 750/750 - 7s - 9ms/step - accuracy: 0.9114 - loss: 0.2514 - val_accuracy: 0.8840 - val_loss: 0.3270 - learning_rate: 0.0010
# Epoch 21/2000
#
# Epoch 21: val_accuracy improved from 0.88625 to 0.88900, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 8s - 11ms/step - accuracy: 0.9140 - loss: 0.2420 - val_accuracy: 0.8890 - val_loss: 0.3243 - learning_rate: 0.0010
# Epoch 22/2000
#
# Epoch 22: val_accuracy did not improve from 0.88900
# 750/750 - 7s - 9ms/step - accuracy: 0.9167 - loss: 0.2378 - val_accuracy: 0.8825 - val_loss: 0.3458 - learning_rate: 0.0010
# Epoch 23/2000
#
# Epoch 23: val_accuracy did not improve from 0.88900
# 750/750 - 8s - 10ms/step - accuracy: 0.9159 - loss: 0.2347 - val_accuracy: 0.8829 - val_loss: 0.3459 - learning_rate: 0.0010
# Epoch 24/2000
#
# Epoch 24: val_accuracy did not improve from 0.88900
# 750/750 - 7s - 10ms/step - accuracy: 0.9188 - loss: 0.2288 - val_accuracy: 0.8887 - val_loss: 0.3329 - learning_rate: 0.0010
# Epoch 25/2000
#
# Epoch 25: val_accuracy did not improve from 0.88900
# 750/750 - 7s - 10ms/step - accuracy: 0.9198 - loss: 0.2239 - val_accuracy: 0.8787 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 26/2000
#
# Epoch 26: val_accuracy improved from 0.88900 to 0.89092, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 8s - 10ms/step - accuracy: 0.9220 - loss: 0.2197 - val_accuracy: 0.8909 - val_loss: 0.3329 - learning_rate: 0.0010
# Epoch 27/2000
#
# Epoch 27: val_accuracy did not improve from 0.89092
# 750/750 - 7s - 9ms/step - accuracy: 0.9232 - loss: 0.2167 - val_accuracy: 0.8834 - val_loss: 0.3560 - learning_rate: 0.0010
# Epoch 28/2000
#
# Epoch 28: val_accuracy did not improve from 0.89092
# 750/750 - 8s - 11ms/step - accuracy: 0.9244 - loss: 0.2107 - val_accuracy: 0.8794 - val_loss: 0.3641 - learning_rate: 0.0010
# Epoch 29/2000
#
# Epoch 29: val_accuracy did not improve from 0.89092
# 750/750 - 7s - 9ms/step - accuracy: 0.9262 - loss: 0.2080 - val_accuracy: 0.8854 - val_loss: 0.3451 - learning_rate: 0.0010
# Epoch 30/2000
#
# Epoch 30: val_accuracy did not improve from 0.89092
# 750/750 - 8s - 10ms/step - accuracy: 0.9271 - loss: 0.2045 - val_accuracy: 0.8879 - val_loss: 0.3364 - learning_rate: 0.0010
# Epoch 31/2000
#
# Epoch 31: val_accuracy did not improve from 0.89092
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 750/750 - 7s - 9ms/step - accuracy: 0.9283 - loss: 0.2011 - val_accuracy: 0.8725 - val_loss: 0.3843 - learning_rate: 0.0010
# Epoch 32/2000
#
# Epoch 32: val_accuracy improved from 0.89092 to 0.89700, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 8s - 11ms/step - accuracy: 0.9396 - loss: 0.1711 - val_accuracy: 0.8970 - val_loss: 0.3315 - learning_rate: 2.0000e-04
# Epoch 33/2000
#
# Epoch 33: val_accuracy improved from 0.89700 to 0.89842, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 10ms/step - accuracy: 0.9451 - loss: 0.1592 - val_accuracy: 0.8984 - val_loss: 0.3347 - learning_rate: 2.0000e-04
# Epoch 34/2000
#
# Epoch 34: val_accuracy did not improve from 0.89842
# 750/750 - 8s - 11ms/step - accuracy: 0.9460 - loss: 0.1532 - val_accuracy: 0.8982 - val_loss: 0.3386 - learning_rate: 2.0000e-04
# Epoch 35/2000
#
# Epoch 35: val_accuracy did not improve from 0.89842
# 750/750 - 7s - 10ms/step - accuracy: 0.9475 - loss: 0.1540 - val_accuracy: 0.8980 - val_loss: 0.3376 - learning_rate: 2.0000e-04
# Epoch 36/2000
#
# Epoch 36: val_accuracy did not improve from 0.89842
# 750/750 - 8s - 10ms/step - accuracy: 0.9476 - loss: 0.1485 - val_accuracy: 0.8982 - val_loss: 0.3416 - learning_rate: 2.0000e-04
# Epoch 37/2000
#
# Epoch 37: val_accuracy did not improve from 0.89842
# 750/750 - 7s - 10ms/step - accuracy: 0.9497 - loss: 0.1429 - val_accuracy: 0.8963 - val_loss: 0.3488 - learning_rate: 2.0000e-04
# Epoch 38/2000
#
# Epoch 38: val_accuracy did not improve from 0.89842
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 750/750 - 8s - 10ms/step - accuracy: 0.9493 - loss: 0.1429 - val_accuracy: 0.8960 - val_loss: 0.3523 - learning_rate: 2.0000e-04
# Epoch 39/2000
#
# Epoch 39: val_accuracy improved from 0.89842 to 0.89983, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 10ms/step - accuracy: 0.9515 - loss: 0.1393 - val_accuracy: 0.8998 - val_loss: 0.3452 - learning_rate: 4.0000e-05
# Epoch 40/2000
#
# Epoch 40: val_accuracy improved from 0.89983 to 0.89992, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 10ms/step - accuracy: 0.9533 - loss: 0.1333 - val_accuracy: 0.8999 - val_loss: 0.3480 - learning_rate: 4.0000e-05
# Epoch 41/2000
#
# Epoch 41: val_accuracy did not improve from 0.89992
# 750/750 - 8s - 10ms/step - accuracy: 0.9534 - loss: 0.1323 - val_accuracy: 0.8996 - val_loss: 0.3483 - learning_rate: 4.0000e-05
# Epoch 42/2000
#
# Epoch 42: val_accuracy improved from 0.89992 to 0.90042, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 7s - 9ms/step - accuracy: 0.9545 - loss: 0.1299 - val_accuracy: 0.9004 - val_loss: 0.3477 - learning_rate: 4.0000e-05
# Epoch 43/2000
#
# Epoch 43: val_accuracy did not improve from 0.90042
# 750/750 - 5s - 6ms/step - accuracy: 0.9551 - loss: 0.1303 - val_accuracy: 0.8999 - val_loss: 0.3512 - learning_rate: 4.0000e-05
# Epoch 44/2000
#
# Epoch 44: val_accuracy did not improve from 0.90042
# 750/750 - 4s - 6ms/step - accuracy: 0.9534 - loss: 0.1316 - val_accuracy: 0.8991 - val_loss: 0.3491 - learning_rate: 4.0000e-05
# Epoch 45/2000
#
# Epoch 45: val_accuracy did not improve from 0.90042
# 750/750 - 5s - 6ms/step - accuracy: 0.9553 - loss: 0.1267 - val_accuracy: 0.9002 - val_loss: 0.3526 - learning_rate: 4.0000e-05
# Epoch 46/2000
#
# Epoch 46: val_accuracy improved from 0.90042 to 0.90050, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.9562 - loss: 0.1284 - val_accuracy: 0.9005 - val_loss: 0.3540 - learning_rate: 4.0000e-05
# Epoch 47/2000
#
# Epoch 47: val_accuracy did not improve from 0.90050
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 750/750 - 6s - 8ms/step - accuracy: 0.9545 - loss: 0.1297 - val_accuracy: 0.8991 - val_loss: 0.3544 - learning_rate: 4.0000e-05
# Epoch 48/2000
#
# Epoch 48: val_accuracy did not improve from 0.90050
# 750/750 - 6s - 8ms/step - accuracy: 0.9553 - loss: 0.1280 - val_accuracy: 0.8997 - val_loss: 0.3536 - learning_rate: 8.0000e-06
# Epoch 49/2000
#
# Epoch 49: val_accuracy did not improve from 0.90050
# 750/750 - 8s - 10ms/step - accuracy: 0.9552 - loss: 0.1279 - val_accuracy: 0.8999 - val_loss: 0.3533 - learning_rate: 8.0000e-06
# Epoch 50/2000
#
# Epoch 50: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 10ms/step - accuracy: 0.9561 - loss: 0.1264 - val_accuracy: 0.9000 - val_loss: 0.3530 - learning_rate: 8.0000e-06
# Epoch 51/2000
#
# Epoch 51: val_accuracy did not improve from 0.90050
# 750/750 - 8s - 11ms/step - accuracy: 0.9567 - loss: 0.1240 - val_accuracy: 0.9001 - val_loss: 0.3538 - learning_rate: 8.0000e-06
# Epoch 52/2000
#
# Epoch 52: val_accuracy did not improve from 0.90050
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 750/750 - 7s - 9ms/step - accuracy: 0.9571 - loss: 0.1255 - val_accuracy: 0.8997 - val_loss: 0.3538 - learning_rate: 8.0000e-06
# Epoch 53/2000
#
# Epoch 53: val_accuracy did not improve from 0.90050
# 750/750 - 8s - 11ms/step - accuracy: 0.9568 - loss: 0.1255 - val_accuracy: 0.8999 - val_loss: 0.3547 - learning_rate: 1.6000e-06
# Epoch 54/2000
#
# Epoch 54: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 9ms/step - accuracy: 0.9560 - loss: 0.1267 - val_accuracy: 0.9002 - val_loss: 0.3548 - learning_rate: 1.6000e-06
# Epoch 55/2000
#
# Epoch 55: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 10ms/step - accuracy: 0.9565 - loss: 0.1240 - val_accuracy: 0.8998 - val_loss: 0.3535 - learning_rate: 1.6000e-06
# Epoch 56/2000
#
# Epoch 56: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 10ms/step - accuracy: 0.9568 - loss: 0.1218 - val_accuracy: 0.9001 - val_loss: 0.3548 - learning_rate: 1.6000e-06
# Epoch 57/2000
#
# Epoch 57: val_accuracy did not improve from 0.90050
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 750/750 - 6s - 8ms/step - accuracy: 0.9557 - loss: 0.1256 - val_accuracy: 0.9000 - val_loss: 0.3552 - learning_rate: 1.6000e-06
# Epoch 58/2000
#
# Epoch 58: val_accuracy did not improve from 0.90050
# 750/750 - 8s - 10ms/step - accuracy: 0.9563 - loss: 0.1280 - val_accuracy: 0.9003 - val_loss: 0.3544 - learning_rate: 3.2000e-07
# Epoch 59/2000
#
# Epoch 59: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 9ms/step - accuracy: 0.9563 - loss: 0.1257 - val_accuracy: 0.8999 - val_loss: 0.3549 - learning_rate: 3.2000e-07
# Epoch 60/2000
#
# Epoch 60: val_accuracy did not improve from 0.90050
# 750/750 - 8s - 11ms/step - accuracy: 0.9561 - loss: 0.1254 - val_accuracy: 0.8997 - val_loss: 0.3538 - learning_rate: 3.2000e-07
# Epoch 61/2000
#
# Epoch 61: val_accuracy did not improve from 0.90050
# 750/750 - 6s - 8ms/step - accuracy: 0.9557 - loss: 0.1269 - val_accuracy: 0.9001 - val_loss: 0.3552 - learning_rate: 3.2000e-07
# Epoch 62/2000
#
# Epoch 62: val_accuracy did not improve from 0.90050
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 750/750 - 8s - 10ms/step - accuracy: 0.9565 - loss: 0.1252 - val_accuracy: 0.8999 - val_loss: 0.3552 - learning_rate: 3.2000e-07
# Epoch 63/2000
#
# Epoch 63: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 9ms/step - accuracy: 0.9563 - loss: 0.1260 - val_accuracy: 0.8997 - val_loss: 0.3550 - learning_rate: 6.4000e-08
# Epoch 64/2000
#
# Epoch 64: val_accuracy did not improve from 0.90050
# 750/750 - 8s - 10ms/step - accuracy: 0.9572 - loss: 0.1247 - val_accuracy: 0.8999 - val_loss: 0.3547 - learning_rate: 6.4000e-08
# Epoch 65/2000
#
# Epoch 65: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 10ms/step - accuracy: 0.9564 - loss: 0.1247 - val_accuracy: 0.8994 - val_loss: 0.3547 - learning_rate: 6.4000e-08
# Epoch 66/2000
#
# Epoch 66: val_accuracy did not improve from 0.90050
# 750/750 - 7s - 10ms/step - accuracy: 0.9562 - loss: 0.1274 - val_accuracy: 0.8997 - val_loss: 0.3544 - learning_rate: 6.4000e-08
# Epoch 66: early stopping
# Restoring model weights from the end of the best epoch: 46.

# %%
hist_df = pd.DataFrame(history.history)
fn_plot_tf_hist(hist_df=hist_df)

# %% [markdown]
# ## checking on validation data

# %%
best_model = tf.keras.models.load_model(chkptPath)

# %%
valid_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.int8, name=None))>

# %%
y_true, y_pred = [],[]
for  feat, lbls in valid_ds:
    # feat, lbls = data  # not needed
    pred = best_model(feat).numpy()# prediction_model(feat) gives output as tensor
    pred = pred.argmax(axis=1)
    y_true.extend(lbls)
    y_pred.extend(pred)

len(y_true), len(y_pred)
# Out:
# (10000, 10000)

# %%
loss, accuracy = best_model.evaluate(valid_ds)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7814 - loss: 45.9414

# %%
loss, accuracy
# Out:
# (47.15907287597656, 0.7864999771118164)

# %% [markdown]
# ## using dropout

# %%
del model1
gc.collect()

gc.collect()
# Out:
# 0

# %%
initializer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

inputs = tf.keras.Input(shape = (train_shape[1], ), name = 'input')
DOR1 = 0.2

DOR2 = .3 # drop out rate i.e 30  % of the neuron's weight will be neglected"

DOR3 = .4

x = tf.keras.layers.Dense(196,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name= 'fc_1')(inputs)

x = tf.keras.layers.BatchNormalization()(x) # batch normalization because the normalizatin of the input does'nt pass on to the hidden layers

x = tf.keras.layers.Activation(activation = 'relu')(x)

# x = tf.keras.layers.Dropout(rate = DOR1)(x)

x = tf.keras.layers.Dense(98,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name = 'fc_2')(x) # it can be understood like a linked list

x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Activation(activation = 'relu')(x)

# x = tf.keras.layers.Dropout(rate = DOR2)(x)

x = tf.keras.layers.Dense(49,
                          # activation = tf.keras.activations.relu,
                          kernel_initializer = initializer, name = 'fc_3')(x) # it can be understood like a linked list

x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Activation(activation = 'relu')(x)

# x = tf.keras.layers.Dropout(rate = DOR3)(x)


outputs = tf.keras.layers.Dense(10 ,
                                kernel_initializer = initializer, name= 'output')(x)
model1 = tf.keras.Model(inputs = inputs, outputs = outputs, name = 'MINST')

# %%
chkptPath = os.path.join(modelDir, subDir, 'all_in.keras')
chkpt_cb = tf.keras.callbacks.ModelCheckpoint(chkptPath,
                                              monitor = 'val_loss',
                                              verbose =2,
                                              save_best_only = True)

es_cb = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                         verbose = 2,
                                         patience = PATIENCE,
                                         restore_best_weights = True)

lr_cb = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                                             factor = LR_FACTOR,
                                             patience = LR_PATIENCE,
                                             verbose = 2)

# %%
model1.summary()
# Out:
# Model: "MINST"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_1 (Dense)                    │ (None, 196)            │       153,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 196)            │           784 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 196)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_2 (Dense)                    │ (None, 98)             │        19,306 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 98)             │           392 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 98)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_3 (Dense)                    │ (None, 49)             │         4,851 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 49)             │           196 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 49)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 179,889 (702.69 KB)
#  Trainable params: 179,203 (700.01 KB)
#  Non-trainable params: 686 (2.68 KB)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model1.compile(optimizer = optimizer, loss = loss_fn, metrics = ['accuracy'])

# %%
history = model1.fit(train_ds, validation_data = test_ds, epochs = EPOCHS, verbose = 2, callbacks = [chkpt_cb, es_cb, lr_cb])
# Out:
# Epoch 1/2000
#
# Epoch 1: val_loss improved from inf to 0.40642, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 10s - 14ms/step - accuracy: 0.8302 - loss: 0.4910 - val_accuracy: 0.8509 - val_loss: 0.4064 - learning_rate: 0.0010
# Epoch 2/2000
#
# Epoch 2: val_loss improved from 0.40642 to 0.37402, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.8739 - loss: 0.3470 - val_accuracy: 0.8643 - val_loss: 0.3740 - learning_rate: 0.0010
# Epoch 3/2000
#
# Epoch 3: val_loss improved from 0.37402 to 0.34337, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.8890 - loss: 0.3004 - val_accuracy: 0.8759 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 4/2000
#
# Epoch 4: val_loss did not improve from 0.34337
# 750/750 - 7s - 9ms/step - accuracy: 0.9031 - loss: 0.2656 - val_accuracy: 0.8735 - val_loss: 0.3526 - learning_rate: 0.0010
# Epoch 5/2000
#
# Epoch 5: val_loss did not improve from 0.34337
# 750/750 - 5s - 7ms/step - accuracy: 0.9120 - loss: 0.2370 - val_accuracy: 0.8733 - val_loss: 0.3605 - learning_rate: 0.0010
# Epoch 6/2000
#
# Epoch 6: val_loss did not improve from 0.34337
# 750/750 - 6s - 7ms/step - accuracy: 0.9210 - loss: 0.2158 - val_accuracy: 0.8761 - val_loss: 0.3554 - learning_rate: 0.0010
# Epoch 7/2000
#
# Epoch 7: val_loss did not improve from 0.34337
# 750/750 - 6s - 8ms/step - accuracy: 0.9294 - loss: 0.1936 - val_accuracy: 0.8717 - val_loss: 0.3729 - learning_rate: 0.0010
# Epoch 8/2000
#
# Epoch 8: val_loss did not improve from 0.34337
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 750/750 - 5s - 7ms/step - accuracy: 0.9351 - loss: 0.1774 - val_accuracy: 0.8650 - val_loss: 0.4039 - learning_rate: 0.0010
# Epoch 9/2000
#
# Epoch 9: val_loss improved from 0.34337 to 0.33346, saving model to ..\model\fashion_mnist\all_in.keras
# 750/750 - 6s - 8ms/step - accuracy: 0.9519 - loss: 0.1352 - val_accuracy: 0.8892 - val_loss: 0.3335 - learning_rate: 2.0000e-04
# Epoch 10/2000
#
# Epoch 10: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9612 - loss: 0.1141 - val_accuracy: 0.8909 - val_loss: 0.3416 - learning_rate: 2.0000e-04
# Epoch 11/2000
#
# Epoch 11: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9664 - loss: 0.1012 - val_accuracy: 0.8900 - val_loss: 0.3530 - learning_rate: 2.0000e-04
# Epoch 12/2000
#
# Epoch 12: val_loss did not improve from 0.33346
# 750/750 - 7s - 9ms/step - accuracy: 0.9709 - loss: 0.0905 - val_accuracy: 0.8892 - val_loss: 0.3669 - learning_rate: 2.0000e-04
# Epoch 13/2000
#
# Epoch 13: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9752 - loss: 0.0803 - val_accuracy: 0.8867 - val_loss: 0.3800 - learning_rate: 2.0000e-04
# Epoch 14/2000
#
# Epoch 14: val_loss did not improve from 0.33346
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 750/750 - 7s - 9ms/step - accuracy: 0.9789 - loss: 0.0711 - val_accuracy: 0.8865 - val_loss: 0.3924 - learning_rate: 2.0000e-04
# Epoch 15/2000
#
# Epoch 15: val_loss did not improve from 0.33346
# 750/750 - 7s - 9ms/step - accuracy: 0.9810 - loss: 0.0632 - val_accuracy: 0.8929 - val_loss: 0.3652 - learning_rate: 4.0000e-05
# Epoch 16/2000
#
# Epoch 16: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9836 - loss: 0.0580 - val_accuracy: 0.8932 - val_loss: 0.3687 - learning_rate: 4.0000e-05
# Epoch 17/2000
#
# Epoch 17: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9848 - loss: 0.0551 - val_accuracy: 0.8930 - val_loss: 0.3722 - learning_rate: 4.0000e-05
# Epoch 18/2000
#
# Epoch 18: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9859 - loss: 0.0526 - val_accuracy: 0.8927 - val_loss: 0.3757 - learning_rate: 4.0000e-05
# Epoch 19/2000
#
# Epoch 19: val_loss did not improve from 0.33346
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 750/750 - 7s - 9ms/step - accuracy: 0.9867 - loss: 0.0503 - val_accuracy: 0.8917 - val_loss: 0.3792 - learning_rate: 4.0000e-05
# Epoch 20/2000
#
# Epoch 20: val_loss did not improve from 0.33346
# 750/750 - 7s - 9ms/step - accuracy: 0.9876 - loss: 0.0480 - val_accuracy: 0.8956 - val_loss: 0.3765 - learning_rate: 8.0000e-06
# Epoch 21/2000
#
# Epoch 21: val_loss did not improve from 0.33346
# 750/750 - 6s - 7ms/step - accuracy: 0.9881 - loss: 0.0468 - val_accuracy: 0.8955 - val_loss: 0.3769 - learning_rate: 8.0000e-06
# Epoch 22/2000
#
# Epoch 22: val_loss did not improve from 0.33346
# 750/750 - 7s - 9ms/step - accuracy: 0.9883 - loss: 0.0461 - val_accuracy: 0.8955 - val_loss: 0.3777 - learning_rate: 8.0000e-06
# Epoch 23/2000
#
# Epoch 23: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9885 - loss: 0.0456 - val_accuracy: 0.8955 - val_loss: 0.3784 - learning_rate: 8.0000e-06
# Epoch 24/2000
#
# Epoch 24: val_loss did not improve from 0.33346
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 750/750 - 7s - 9ms/step - accuracy: 0.9886 - loss: 0.0450 - val_accuracy: 0.8953 - val_loss: 0.3793 - learning_rate: 8.0000e-06
# Epoch 25/2000
#
# Epoch 25: val_loss did not improve from 0.33346
# 750/750 - 7s - 9ms/step - accuracy: 0.9890 - loss: 0.0441 - val_accuracy: 0.8956 - val_loss: 0.3796 - learning_rate: 1.6000e-06
# Epoch 26/2000
#
# Epoch 26: val_loss did not improve from 0.33346
# 750/750 - 5s - 7ms/step - accuracy: 0.9890 - loss: 0.0440 - val_accuracy: 0.8954 - val_loss: 0.3797 - learning_rate: 1.6000e-06
# Epoch 27/2000
#
# Epoch 27: val_loss did not improve from 0.33346
# 750/750 - 7s - 9ms/step - accuracy: 0.9891 - loss: 0.0438 - val_accuracy: 0.8952 - val_loss: 0.3799 - learning_rate: 1.6000e-06
# Epoch 28/2000
#
# Epoch 28: val_loss did not improve from 0.33346
# 750/750 - 6s - 8ms/step - accuracy: 0.9892 - loss: 0.0437 - val_accuracy: 0.8951 - val_loss: 0.3801 - learning_rate: 1.6000e-06
# Epoch 29/2000
#
# Epoch 29: val_loss did not improve from 0.33346
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 750/750 - 6s - 9ms/step - accuracy: 0.9893 - loss: 0.0436 - val_accuracy: 0.8952 - val_loss: 0.3803 - learning_rate: 1.6000e-06
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
hist_df = pd.DataFrame(history.history)
fn_plot_tf_hist(hist_df=hist_df)

# %% [markdown]
# ## checking on validation data

# %%
best_model = tf.keras.models.load_model(chkptPath)

# %%
valid_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.int8, name=None))>

# %%
y_true, y_pred = [],[]
for  feat, lbls in valid_ds:
    # feat, lbls = data  # not needed
    pred = best_model(feat).numpy()# prediction_model(feat) gives output as tensor
    pred = pred.argmax(axis=1)
    y_true.extend(lbls)
    y_pred.extend(pred)

len(y_true), len(y_pred)
# Out:
# (10000, 10000)

# %%
loss, accuracy = best_model.evaluate(valid_ds)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6558 - loss: 90.8251

# %%
loss, accuracy
# Out:
# (91.70319366455078, 0.65829998254776)
